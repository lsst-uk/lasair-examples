# %% [markdown]
# ## Sherlock illustration
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html
#
# In this notebook, we use the Lasair API to invoke Sherlock,
# to find the likely host galaxy if there were an alert there. It shows how there can be
# multiple possible matches, including repeats, but Sherlock chooses the best one.
#
# *IMPORTANT*: this notebook is to explain how Sherlock works. Lasair computes the Sherlock
# crossmatch for every alert anyway, so you need not call the API, but rather use the
# table supplied in the filter builder.

# %%
import sys, json
import matplotlib.pyplot as plt
import lasair
sys.path.append('..')
import settings

# %%
endpoint='https://api.lasair.lsst.ac.uk/api'
L = lasair.lasair_client(settings.API_TOKEN, endpoint=endpoint)

# %%
# Carefully chosen sky point near four galaxies
ra = 150.096944
dec =  1.636908

# %%
# If `lite=True` (the default), you just get the best guess rather than all possible crossmatches
sherl = L.sherlock_position(ra, dec, lite=False)
print(json.dumps(sherl, indent=2))
# Out:
# {
#   "classifications": {
#     "query0": [
#       "SN",
#       "The transient is possibly associated with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=COSMOS0557037&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">COSMOS0557037</a></em>; a 23.50 mag VisS found in the NED catalogue. It's located 1.03\" S, 2.65\" E from the VisS centre. A host photoZ=0.490 implies a <em>m - M =</em> 42.21."
#     ]
#   },
#   "crossmatches": [
#     {
#       "association_type": "SN",
#       "best_distance": 2765.06,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557037",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63719444444,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.6473",
#       "merged_rank": null,
#       "northSeparationArcsec": "1.0312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.49,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2765.06,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.21,
#       "pz_distance_scale": 6.04,
#       "raDeg": 150.096208333,
#       "rank": 1,
#       "rankScore": 3002.047351170052,
#       "search_name": "NED",
#       "separationArcsec": 2.8410702031219657,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.5,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 2563.92,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557044",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63611111111,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-0.5482",
#       "merged_rank": null,
#       "northSeparationArcsec": "-2.8688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.46,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2563.92,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.04,
#       "pz_distance_scale": 5.83,
#       "raDeg": 150.096791667,
#       "rank": 2,
#       "rankScore": 3002.0486783879296,
#       "search_name": "NED",
#       "separationArcsec": 2.9207032757784583,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.8,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 2697.64,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557282",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63663888889,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "2.9",
#       "merged_rank": null,
#       "northSeparationArcsec": "-1.0",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.48,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2697.64,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.15,
#       "pz_distance_scale": 5.97,
#       "raDeg": 150.09775,
#       "rank": 3,
#       "rankScore": 3002.0509656271815,
#       "search_name": "NED",
#       "separationArcsec": 3.057937630882475,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 22.7,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 3673.49,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557032",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63763888889,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.3474",
#       "merged_rank": null,
#       "northSeparationArcsec": "2.6312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.62,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 3673.49,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.83,
#       "pz_distance_scale": 6.79,
#       "raDeg": 150.096291667,
#       "rank": 4,
#       "rankScore": 3002.0587690498655,
#       "search_name": "NED",
#       "separationArcsec": 3.5261429919328515,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 22.5,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": null,
#       "best_distance_flag": null,
#       "best_distance_source": null,
#       "catalogue_object_id": "COSMOS0557076",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63616666667,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-3.2471",
#       "merged_rank": null,
#       "northSeparationArcsec": "-2.6688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": null,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": null,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": null,
#       "pz_distance_scale": null,
#       "raDeg": 150.096041667,
#       "rank": 5,
#       "rankScore": 3002.0700515236326,
#       "search_name": "NED",
#       "separationArcsec": 4.2030914179559,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 22.0,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 3038.38,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557908",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63558333333,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-1.2979",
#       "merged_rank": null,
#       "northSeparationArcsec": "-4.7688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.53,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 3038.38,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.41,
#       "pz_distance_scale": 6.29,
#       "raDeg": 150.096583333,
#       "rank": 6,
#       "rankScore": 3002.0823709823107,
#       "search_name": "NED",
#       "separationArcsec": 4.942258938642499,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.9,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 2697.64,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557077",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63569444444,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.7973",
#       "merged_rank": null,
#       "northSeparationArcsec": "-4.3688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.48,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2697.64,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.15,
#       "pz_distance_scale": 5.97,
#       "raDeg": 150.096166667,
#       "rank": 7,
#       "rankScore": 3002.086459800284,
#       "search_name": "NED",
#       "separationArcsec": 5.187588017029997,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.4,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 1673.01,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557063",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63697222222,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-5.1963",
#       "merged_rank": null,
#       "northSeparationArcsec": "0.2312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.32,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 1673.01,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 41.12,
#       "pz_distance_scale": 4.66,
#       "raDeg": 150.0955,
#       "rank": 8,
#       "rankScore": 3002.0866903278898,
#       "search_name": "NED",
#       "separationArcsec": 5.201419673385658,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.0,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 3387.9,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557075",
#       "catalogue_object_subtype": "multiple",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "multiple",
#       "classificationReliability": 3,
#       "decDeg": 1.63747222222,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-5.4962",
#       "merged_rank": null,
#       "northSeparationArcsec": "2.0312",
#       "original_search_radius_arcsec": "multiple",
#       "photoZ": 0.58,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 3387.9,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 42.65,
#       "pz_distance_scale": 6.58,
#       "raDeg": 150.095416667,
#       "rank": 9,
#       "rankScore": 3002.097657978117,
#       "search_name": "NED",
#       "separationArcsec": 5.859478686996958,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.3,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557075",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63747222222,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-5.4962",
#       "merged_rank": 9,
#       "northSeparationArcsec": "2.0312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.58,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 3387.9,
#       "pz_distance_modulus": 42.65,
#       "pz_distance_scale": 6.58,
#       "raDeg": 150.095416667,
#       "rankScore": 3002.097657978117,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 5.859478686996958,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.3,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557074",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63761111111,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-5.3462",
#       "merged_rank": 9,
#       "northSeparationArcsec": "2.5312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.59,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 3458.81,
#       "pz_distance_modulus": 42.69,
#       "pz_distance_scale": 6.63,
#       "raDeg": 150.095458333,
#       "rankScore": 3002.097657978117,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 5.9151511093106315,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.3,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 25213.47,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0558128",
#       "catalogue_object_subtype": "multiple",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "multiple",
#       "classificationReliability": 3,
#       "decDeg": 1.63680555556,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-6.3958",
#       "merged_rank": null,
#       "northSeparationArcsec": "-0.3688",
#       "original_search_radius_arcsec": "multiple",
#       "photoZ": 2.98,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 25213.47,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 47.01,
#       "pz_distance_scale": 7.72,
#       "raDeg": 150.095166667,
#       "rank": 10,
#       "rankScore": 3002.1067735411634,
#       "search_name": "NED",
#       "separationArcsec": 6.406412469801142,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.0,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0558128",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63680555556,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-6.3958",
#       "merged_rank": 10,
#       "northSeparationArcsec": "-0.3688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 2.98,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 25213.47,
#       "pz_distance_modulus": 47.01,
#       "pz_distance_scale": 7.72,
#       "raDeg": 150.095166667,
#       "rankScore": 3002.1067735411634,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 6.406412469801142,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.0,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557083",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63661111111,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-6.55",
#       "merged_rank": 10,
#       "northSeparationArcsec": "-1.07",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 3.0,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 25417.2,
#       "pz_distance_modulus": 47.0,
#       "pz_distance_scale": 7.7,
#       "raDeg": 150.095125,
#       "rankScore": 3002.1067735411634,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 6.6324121379271554,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 22.1,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557084",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63644444444,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-6.6957",
#       "merged_rank": 10,
#       "northSeparationArcsec": "-1.6688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.09,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 411.48,
#       "pz_distance_modulus": 38.07,
#       "pz_distance_scale": 1.68,
#       "raDeg": 150.095083333,
#       "rankScore": 3002.1067735411634,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 6.900498431384718,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 22.6,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 4259.5,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557566",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63713888889,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-6.8456",
#       "merged_rank": null,
#       "northSeparationArcsec": "0.8312",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.7,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 4259.5,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 43.1,
#       "pz_distance_scale": 7.1,
#       "raDeg": 150.095041667,
#       "rank": 11,
#       "rankScore": 3002.114931353887,
#       "search_name": "NED",
#       "separationArcsec": 6.895881233220532,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.8,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 2108.22,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557072",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63508333333,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.95",
#       "merged_rank": null,
#       "northSeparationArcsec": "-6.57",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.39,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2108.22,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 41.62,
#       "pz_distance_scale": 5.29,
#       "raDeg": 150.096125,
#       "rank": 12,
#       "rankScore": 3002.119994329607,
#       "search_name": "NED",
#       "separationArcsec": 7.199659776414051,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.6,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 8364.24,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0558028",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63530555556,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "5.2994",
#       "merged_rank": null,
#       "northSeparationArcsec": "-5.7688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 1.21,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 8364.24,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 44.61,
#       "pz_distance_scale": 8.3,
#       "raDeg": 150.098416667,
#       "rank": 13,
#       "rankScore": 3002.1305576914165,
#       "search_name": "NED",
#       "separationArcsec": 7.833461484991979,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.1,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 5563.44,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557059",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63794444444,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-7.45",
#       "merged_rank": null,
#       "northSeparationArcsec": "3.73",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.87,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 5563.44,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 43.73,
#       "pz_distance_scale": 7.71,
#       "raDeg": 150.094875,
#       "rank": 14,
#       "rankScore": 3002.1387996430553,
#       "search_name": "NED",
#       "separationArcsec": 8.327978583311843,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 23.3,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 1856.91,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557154",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63472222222,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.95",
#       "merged_rank": null,
#       "northSeparationArcsec": "-7.87",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.35,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 1856.91,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 41.34,
#       "pz_distance_scale": 4.94,
#       "raDeg": 150.096125,
#       "rank": 15,
#       "rankScore": 3002.140043632119,
#       "search_name": "NED",
#       "separationArcsec": 8.402617927138003,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.5,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "best_distance": 2044.76,
#       "best_distance_flag": "pz",
#       "best_distance_source": "NED",
#       "catalogue_object_id": "COSMOS0557067",
#       "catalogue_object_subtype": "multiple",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "multiple",
#       "classificationReliability": 3,
#       "decDeg": 1.63452777778,
#       "direct_distance": null,
#       "direct_distance_cat": "NED",
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-1.8976",
#       "merged_rank": null,
#       "northSeparationArcsec": "-8.5688",
#       "original_search_radius_arcsec": "multiple",
#       "photoZ": 0.38,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2044.76,
#       "pz_distance_cat": "NED",
#       "pz_distance_modulus": 41.55,
#       "pz_distance_scale": 5.21,
#       "raDeg": 150.096416667,
#       "rank": 16,
#       "rankScore": 3002.1462734486245,
#       "search_name": "NED",
#       "separationArcsec": 8.776406917467117,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.6,
#       "z": null,
#       "z_distance": null,
#       "z_distance_cat": "NED",
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557067",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63452777778,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-1.8976",
#       "merged_rank": 16,
#       "northSeparationArcsec": "-8.5688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.38,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2044.76,
#       "pz_distance_modulus": 41.55,
#       "pz_distance_scale": 5.21,
#       "raDeg": 150.096416667,
#       "rankScore": 3002.1462734486245,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 8.776406917467117,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.6,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     },
#     {
#       "association_type": "SN",
#       "catalogue_object_id": "COSMOS 0557068",
#       "catalogue_object_subtype": "VisS",
#       "catalogue_object_type": "galaxy",
#       "catalogue_table_id": 68,
#       "catalogue_table_name": "NED",
#       "catalogue_view_id": 39,
#       "catalogue_view_name": "tcs_view_galaxy_like_ned_stream",
#       "classificationReliability": 3,
#       "decDeg": 1.63436111111,
#       "direct_distance": null,
#       "direct_distance_modulus": null,
#       "direct_distance_scale": null,
#       "eastSeparationArcsec": "-2.3474",
#       "merged_rank": 16,
#       "northSeparationArcsec": "-9.1688",
#       "original_search_radius_arcsec": 10.0,
#       "photoZ": 0.41,
#       "photoZErr": null,
#       "physical_separation_kpc": null,
#       "pz_distance": 2236.41,
#       "pz_distance_modulus": 41.75,
#       "pz_distance_scale": 5.45,
#       "raDeg": 150.096291667,
#       "rankScore": 3002.1462734486245,
#       "search_name": "ned phot galaxy-like angular",
#       "separationArcsec": 9.46453235829454,
#       "sm_axis_arcsec": null,
#       "transient_object_id": "query0",
#       "unkMag": 24.3,
#       "z": null,
#       "z_distance": null,
#       "z_distance_modulus": null,
#       "z_distance_scale": null
#     }
#   ]
# }

# %% [markdown]
# ### All the crossmatches
# First is sherlock's opinion of this match (lower rank is better),
# then the delta position in arcseconds from the given position,
# then the catalogue from which the object came.

# %%
size = 50
elist = [0.0]
nlist = [0.0]
slist = [size]
print('rank  east arcsec  north arcsec catalogue')
for cm in sherl['crossmatches']:
    if not 'rank' in cm: continue
    e =  float(cm['eastSeparationArcsec'])
    n = -float(cm['northSeparationArcsec'])
    print('%2s      %8.2f %8.2f          %s' % (cm['rank'], e, n, cm['catalogue_table_name']))
    elist.append(e)
    nlist.append(n)
    slist.append(size/int(cm['rank'] + 1))
# Out:
# rank  east arcsec  north arcsec catalogue
#  1         -2.65    -1.03          NED
#  2         -0.55     2.87          NED
#  3          2.90     1.00          NED
#  4         -2.35    -2.63          NED
#  5         -3.25     2.67          NED
#  6         -1.30     4.77          NED
#  7         -2.80     4.37          NED
#  8         -5.20    -0.23          NED
#  9         -5.50    -2.03          NED
# 10         -6.40     0.37          NED
# 11         -6.85    -0.83          NED
# 12         -2.95     6.57          NED
# 13          5.30     5.77          NED
# 14         -7.45    -3.73          NED
# 15         -2.95     7.87          NED
# 16         -1.90     8.57          NED

# %% [markdown]
# We can plot the alert (centre) and the various crossmatches found by Sherlock.
# The largest symbol (rank=1) is where Sherlock decides is the correct host galaxy for this alert.

# %%
plt.scatter(elist, nlist, s=slist)
plt.xlim((-4, 4)) 
plt.ylim((-4, 4)) 
plt.xlabel('arcsec from alert')
plt.ylabel('arcsec from alert')
plt.annotate('alert', (0,0))
plt.annotate('choice', (elist[1],nlist[1]))
plt.show()
