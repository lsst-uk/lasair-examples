# %% [markdown]
# # Test notebook to exercise the Lasair API
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html

# %%
import sys, json
sys.path.append('..')
import settings
from lasair import LasairError, lasair_client as lasair
endpoint = "https://api.lasair.lsst.ac.uk/api"

# %%
L = lasair(settings.API_TOKEN, endpoint=endpoint)

# %% [markdown]
# This function simply prints the first lines of the given string.
# You can replace it with the normal print if you want to see everything.

# %%
def print15(s):
    print('\n'.join(s.split('\n')[:15]))

# %% [markdown]
# ## Sherlock Object

# %%
lite=True
objectId = 170028510770888728
result = L.sherlock_object(objectId, lite=lite)
print15(json.dumps(result, indent=2))
# Out:
# {
#   "classifications": {
#     "170028510770888728": [
#       "SN",
#       "The transient is possibly associated with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=2MASXJ10030770%2B0321017&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">2MASXJ10030770%2B0321017</a></em>; an r=15.17 mag galaxy found in the NED-D/SDSS catalogues. It's located 25.16\" S, 13.69\" W (38.0 Kpc) from the galaxy centre. A host distance of 274.0 Mpc(z=0.058) implies a <em>m - M =</em> 37.19."
#     ]
#   },
#   "crossmatches": [
#     {
#       "Mag": 15.169,
#       "MagErr": 0.473,
#       "MagFilter": "r",
#       "association_type": "SN",
#       "best_distance": 274.0,
#       "best_distance_flag": "dd",

# %% [markdown]
# ## Sherlock Position

# %%
ra  = 150.778316
dec =   3.343371
result = L.sherlock_position(ra, dec, lite=lite)
print15(json.dumps(result, indent=2))
# Out:
# {
#   "classifications": {
#     "query0": [
#       "SN",
#       "The transient is possibly associated with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=2MASXJ10030770%2B0321017&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">2MASXJ10030770%2B0321017</a></em>; an r=15.17 mag galaxy found in the NED-D/SDSS catalogues. It's located 25.16\" S, 13.69\" W (38.0 Kpc) from the galaxy centre. A host distance of 274.0 Mpc(z=0.058) implies a <em>m - M =</em> 37.19."
#     ]
#   },
#   "crossmatches": [
#     {
#       "Mag": 15.169,
#       "MagErr": 0.473,
#       "MagFilter": "r",
#       "association_type": "SN",
#       "best_distance": 274.0,
#       "best_distance_flag": "dd",
