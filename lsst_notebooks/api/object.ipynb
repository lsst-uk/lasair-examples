# %% [markdown]
# # Object API call
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html
#
# The purpose of this notebook is to show the four different styles of output from the API `object()` call.

# %%
import sys, time, json
from lasair import LasairError, lasair_client as lasair
sys.path.append('..')
import settings

# %%
endpoint = "https://api.lasair.lsst.ac.uk/api"
L = lasair(settings.API_TOKEN, endpoint=endpoint)

# %% [markdown]
# This function summarizes the JSON output. You can use normal `print()` of course
# but there may be a large amount of output.

# %%
def printobj(name, obj, indent=''):
    if indent=='':
        print('Size of object is ', len(json.dumps(obj)), 'bytes')
    if isinstance(obj, list):
        print('%s%s is a list of %d items' % (indent, name, len(obj)))
        if len(obj) > 0:
            printobj(name+'[0]', obj[0], indent=indent+'  ')
    elif isinstance(obj, dict):
        kks = list(obj.keys())
        if len(kks) > 5:
            print('%s%s is a dict of %d items, first 5 are' % (indent, name, len(kks)))
            kks = kks[:5]
        else:
            print('%s%s is a dict of %d items' % (indent, name, len(kks)))
        for kk in kks[:5]:
            printobj(kk, obj[kk], indent=indent+'  ')
    else:
        print('%s%s: %s' % (indent, name, obj))

# %% [markdown]
# #### get a working object with a Sherlock

# %%
selected = 'objects.diaObjectId, objects.ra, objects.decl'
tables = 'objects,sherlock_classifications'
conditions = 'nDiaSources > 4 AND classification="SN"'
results = L.query(selected, tables, conditions, limit = 1)
objectId = results[0]['diaObjectId']
print('diaObjectId %s at (ra, dec) = (%.4f, %.4f)' % (objectId, results[0]['ra'], results[0]['decl']))
# Out:
# diaObjectId 170019716254926219 at (ra, dec) = (149.5695, 0.6022)

# %% [markdown]
# ## All object data

# %%
t = time.time()
result = L.object(objectId, lasair_added=False, lite=True)
print('Time taken = %.3f seconds' % (time.time()-t))
printobj('object', result)
# Out:
# Time taken = 0.272 seconds
# Size of object is  30613 bytes
# object is a dict of 3 items
#   diaObjectId: 170019716254926219
#   diaSourcesList is a list of 90 items
#     diaSourcesList[0] is a dict of 6 items, first 5 are
#       diaSourceId: 170019716254926219
#       midpointMjdTai: 61088.211979366155
#       band: r
#       psfFlux: 2476.949951171875
#       psfFluxErr: 142.22486877441406
#   diaForcedSourcesList is a list of 122 items
#     diaForcedSourcesList[0] is a dict of 4 items
#       midpointMjdTai: 61090.1077735384
#       band: i
#       psfFlux: 2593.3173828125
#       psfFluxErr: 303.6029052734375

# %%
t = time.time()
result = L.object(objectId, lasair_added=False, lite=False)
print('Time taken = %.3f seconds' % (time.time()-t))
printobj('object', result)
# Out:
# Time taken = 0.544 seconds
# Size of object is  306729 bytes
# object is a dict of 4 items
#   diaObjectId: 170019716254926219
#   diaObject is a dict of 82 items, first 5 are
#     diaObjectId: 170019716254926219
#     decErr: 1.0467079846421257e-05
#     decl: 0.6021531657953515
#     firstDiaSourceMjdTai: nan
#     g_fpFluxMean: nan
#   diaSourcesList is a list of 90 items
#     diaSourcesList[0] is a dict of 98 items, first 5 are
#       diaObjectId: 170019716254926219
#       midpointMjdTai: 61088.211979366155
#       diaSourceId: 170019716254926219
#       apFlux: 2754.763427734375
#       apFluxErr: 370.7320861816406
#   diaForcedSourcesList is a list of 122 items
#     diaForcedSourcesList[0] is a dict of 14 items, first 5 are
#       diaObjectId: 170019716254926219
#       midpointMjdTai: 61090.1077735384
#       band: i
#       decl: 0.602169687659609
#       detector: 78

# %%
t = time.time()
result = L.object(objectId, lasair_added=True, lite=True)
print('Time taken = %.3f seconds' % (time.time()-t))
printobj('object', result)
# Out:
# Time taken = 0.462 seconds
# Size of object is  60386 bytes
# object is a dict of 5 items
#   diaObjectId: 170019716254926219
#   lasairData is a dict of 30 items, first 5 are
#     nDiaSources: 89
#     firstDiaSourceMjdTai: 61088.211979366155
#     lastDiaSourceMjdTai: 61091.28458085817
#     glat: 40.7358
#     ebv: 0.0266758
#   diaObject is a dict of 4 items
#     ra: 149.56945133749403
#     decl: 0.6021531657953515
#     firstDiaSourceMjdTai: 61088.211979366155
#     lastDiaSourceMjdTai: 61091.28458085817
#   diaSourcesList is a list of 90 items
#     diaSourcesList[0] is a dict of 6 items, first 5 are
#       diaSourceId: 170032928377536808
#       midpointMjdTai: 61091.28504779168
#       band: i
#       psfFlux: 3161.933837890625
#       psfFluxErr: 443.53082275390625
#   diaForcedSourcesList is a list of 122 items
#     diaForcedSourcesList[0] is a dict of 4 items
#       midpointMjdTai: 61090.1077735384
#       band: i
#       psfFlux: 2593.3173828125
#       psfFluxErr: 303.6029052734375

# %%
t = time.time()
result = L.object(objectId, lasair_added=True, lite=False)
print('Time taken = %.3f seconds' % (time.time()-t))
printobj('object', result)
# Out:
# Time taken = 0.607 seconds
# Size of object is  337274 bytes
# object is a dict of 5 items
#   diaObjectId: 170019716254926219
#   lasairData is a dict of 150 items, first 5 are
#     diaObjectId: 170019716254926219
#     lastDiaSourceMjdTai: 61091.28458085817
#     firstDiaSourceMjdTai: 61088.211979366155
#     u_psfFlux: None
#     u_latestMJD: None
#   diaObject is a dict of 4 items
#     ra: 149.56945133749403
#     decl: 0.6021531657953515
#     firstDiaSourceMjdTai: 61088.211979366155
#     lastDiaSourceMjdTai: 61091.28458085817
#   diaSourcesList is a list of 90 items
#     diaSourcesList[0] is a dict of 98 items, first 5 are
#       diaObjectId: 170019716254926219
#       midpointMjdTai: 61091.28504779168
#       diaSourceId: 170032928377536808
#       apFlux: 2141.3203125
#       apFluxErr: 1024.5264892578125
#   diaForcedSourcesList is a list of 122 items
#     diaForcedSourcesList[0] is a dict of 14 items, first 5 are
#       diaObjectId: 170019716254926219
#       midpointMjdTai: 61090.1077735384
#       band: i
#       decl: 0.602169687659609
#       detector: 78
