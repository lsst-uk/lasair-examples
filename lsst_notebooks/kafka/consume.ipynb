# %% [markdown]
# # Test notebook to exercise the alert consumers
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html

# %%
import sys
import json
from lasair import lasair_consumer

# %% [markdown]
# ## Normal Consumer

# %%
kafka_server = 'lasair-lsst-kafka.lsst.ac.uk:9092'   # prod
topic        = "lasair_1Lightweight"    # prod

#kafka_server = 'lasair-lsst-dev-kafka.lsst.ac.uk:9092'    # dev
#topic        = 'lasair_2lightweight'   # dev

# %%
group_id     = 'test122'
consumer = lasair_consumer(
    kafka_server,    
    group_id,        # any string
    topic            # topic name for your filter
)

n = 0
while n < 10:
    msg = consumer.poll(timeout=20)
    if msg is None:
        print('sleeping 5')
        time.sleep(5)
        continue
    if msg.error():
        print(str(msg.error()))
        break
    jmsg = json.loads(msg.value())
    print(json.dumps(jmsg, indent=2))
    n += 1
print('No more messages available')
# Out:
# {
#   "diaObjectId": 169623885913784335,
#   "decl": -43.5934095376928,
#   "ra": 10.585482824763098
# }
# {
#   "diaObjectId": 169342392068997184,
#   "decl": -44.532587721927264,
#   "ra": 10.5938738923493
# }
# {
#   "diaObjectId": 169522733189169164,
#   "decl": -44.10212206627493,
#   "ra": 9.547343373531119
# }
# {
#   "diaObjectId": 169562328763203617,
#   "decl": -47.291820010476826,
#   "ra": 61.27972384465401
# }
# {
#   "diaObjectId": 169579899615445113,
#   "decl": -44.28508042546649,
#   "ra": 7.97659507746347
# }
# {
#   "diaObjectId": 169342390704275497,
#   "decl": -44.047146575613645,
#   "ra": 10.294419848385726
# }
# {
#   "diaObjectId": 169355604683916228,
#   "decl": -45.049942825349795,
#   "ra": 9.19960629975868
# }
# {
#   "diaObjectId": 169562328760582199,
#   "decl": -46.79026802830261,
#   "ra": 61.69627543311491
# }
# sleeping 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 13
#      11 if msg is None:
#      12     print('sleeping 5')
# ---> 13     time.sleep(5)
#      14     continue
#      15 if msg.error():
#
# NameError: name 'time' is not defined
# %4|1771765923.962|MAXPOLL|rdkafka#consumer-7| [thrd:main]: Application maximum poll interval (300000ms) exceeded by 276ms (adjust max.poll.interval.ms for long-running message processing): leaving group
