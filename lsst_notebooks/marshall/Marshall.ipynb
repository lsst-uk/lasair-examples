# %%
import sys
sys.path.append('/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages')

# %%
# %run code/WidgetsLive.ipynb
# %run code/ShowCutouts.ipynb
# %run code/ShowPS1.ipynb
# %run code/HandleFilterRow.ipynb
# Out:
# /Users/rwillia5/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # A Marshall for Lasair filter output
# Show lightcurve and cutouts from given Lasair topic
# with option to build veto list (dont show me this object again),
# as well as favourite list, each with a reason given.
# Stored on users own machine.
# This notebook only works with [Kafka-streamed filters](https://lasair.readthedocs.io/en/main/core_functions/alert-streams.html).
# After you change your filter to Kafka streaming, it will take a few days for
# alerts to accumulate.
# - First find the topic name in your filter page, and put it in the next cell. Or uncomment one of the samples.

# %%
# Uncomment one of these or put in your own
my_topic     = 'lasair_6ZooniverseTestSN-likecandidatesinlast14days'
#my_topic     = 'lasair_418SN-likethings'
#my_topic     = 'lasair_23CLQ-candidates'
# my_topic    = '....'

# %% [markdown]
# The `group_id` is like a bookmark: the kafka server remembers the last alert it gave you.
# [More here about `group_id`](https://lasair.readthedocs.io/en/main/core_functions/alert-streams.html).
# - Choose a new arbitrary string in the next cell

# %%
group_id     = 'roysgroupid992'

# %% [markdown]
# The function `group_id_to_end()` is a convenience if you want the bookmark all the way to end.
# You will then need to wait a few days for fresh alerts to accumulate.

# %%
# Should normally be commented out.
#group_id_to_end(kafka_server, group_id, my_topic)

# %% [markdown]
# - You will need to set your Lasair API token in a file called `settings.py`.

# %%
# settings.py has a single line like
# API_TOKEN = '8c97c954dxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
token         = settings.API_TOKEN

# %% [markdown]
# Some parameters to drive the Marshall

# %%
lasairUrl     = "https://lasair-ztf.lsst.ac.uk/"
kafka_server = 'kafka.lsst.ac.uk:9092'

# Once a pages is finished, just run the last run() cell again for more
alertsPerPage = 10

# Much faster without images
renderImages = True

# This is where the vetos and favourites are stored
vetoFile      = my_topic + 'veto.txt'
faveFile      = my_topic + 'fave.txt'

# %% [markdown]
# You can now run the last cell of this notebook repeatedly (the `run()` function),
# until there are no more. You can check the 'veto' box and you won't see that object
# again. Similarly with the 'fave' box for favourites. You can write a reason
# along with the checkbox. Remember to click button 'Save veto/fave' at the bottom of
# the page to save your choices. Then come back in a day or more and look at more.

# %%
run(token, kafka_server, group_id, my_topic, alertsPerPage, renderImages)
# Out:
# <h1>Topic lasair_6ZooniverseTestSN-likecandidatesinlast14days</h1>
# Connected to Kafka
# Fetching ['ZTF24abvkvez', 'ZTF24abcubhz', 'ZTF24abnrois', 'ZTF24ablmyli', 'ZTF24abwcujs', 'ZTF24abwzbei', 'ZTF24aagkbnf', 'ZTF24aavmnbq', 'ZTF23abeohgr', 'ZTF24ablknoq']
# 10 in filter list and 10 in object list
# Object data fetched in 2 seconds
# <hr style="height:5px;">
# {'objectId': 'ZTF24abvkvez', 'ramean': 1.8733100599999997, 'decmean': 29.234531574999995, 'mjdmin': 60651.20689810021, 'mjdmax': 60681.151493099984, 'magrmin': 13.351, 'rmag': 13.3513, 'classification': 'ORPHAN', 'score': 'Not Near PS1 star', 'UTC': '2025-01-06 04:02:09'}
# <h2><a href=https://lasair-ztf.lsst.ac.uk//objects/ZTF24abvkvez>ZTF24abvkvez</a></h2><table><tr><th>  objectId</th><th>    ramean</th><th>   decmean</th><th>    mjdmin</th><th>    mjdmax</th><th>   magrmin</th><th>      rmag</th><th>classification</th><th>     score</th><th>       UTC</th></tr><tr><td>ZTF24abvkvez</td><td>  1.873310</td><td> 29.234532</td><td>60651.206898</td><td>60681.151493</td><td> 13.351000</td><td> 13.351300</td><td>    ORPHAN</td><td>Not Near PS1 star</td><td>2025-01-06 04:02:09</td></tr></table>
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run(token, kafka_server, group_id, my_topic, alertsPerPage, renderImages)
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/222434375.py:59, in run(token, kafka_server, group_id, my_topic, alertsPerPage, renderImages)
#      57         display(HTML(s))
#      58         continue
# ---> 59     handle_filter_row(L, filter_row, objectData, renderImages)
#      60     n += 1
#      62 display(HTML('<hr style="height:5px;"> Displayed %d filter rows. Run all cells to get more' % n))
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/1005909756.py:47, in handle_filter_row(L, filter_row, objectData, renderImages)
#      45 # PS1 image
#      46 if renderImages:
# ---> 47     showPS1(axs[3], objectData['objectData'])
#      49 # Lightcurve
#      50 ax = axs[0]
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/986983642.py:2, in showPS1(ax, objectData)
#       1 def showPS1(ax, objectData):
# ----> 2     cim = getcolorim(
#       3         objectData['ramean'], objectData['decmean'],
#       4         size=300,
#       5         filters="grz")
#       6     ax.get_xaxis().set_visible(False)
#       7     ax.get_yaxis().set_visible(False)
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/1599234515.py:16, in getcolorim(ra, dec, size, output_size, filters, format)
#      14 if format not in ("jpg","png"):
#      15     raise ValueError("format must be jpg or png")
# ---> 16 url = geturl(ra,dec,size=size,filters=filters,output_size=output_size,format=format,color=True)
#      17 r = requests.get(url)
#      18 im = Image.open(BytesIO(r.content))
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/4106225913.py:20, in geturl(ra, dec, size, output_size, filters, format, color)
#      18 if format not in ("jpg","png","fits"):
#      19     raise ValueError("format must be one of jpg, png, fits")
# ---> 20 table = getimages(ra,dec,filters=filters)
#      21 url = (f"https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?"
#      22        f"ra={ra}&dec={dec}&size={size}&format={format}")
#      23 if output_size:
#
# File /var/folders/j6/mk7_l2dd46vff9s6lzfnj9nr0000gn/T/ipykernel_14982/686536999.py:13, in getimages(ra, dec, filters)
#      11 service = "https://ps1images.stsci.edu/cgi-bin/ps1filenames.py"
#      12 url = f"{service}?ra={ra}&dec={dec}&filters={filters}"
# ---> 13 table = Table.read(url, format='ascii')
#      14 return table
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/registry/core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/ascii/connect.py:19, in io_read(format, filename, **kwargs)
#      17     format = re.sub(r"^ascii\.", "", format)
#      18     kwargs["format"] = format
# ---> 19 return read(filename, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/decorators.py:604, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     601             msg += f"\n        Use {alternative} instead."
#     602         warnings.warn(msg, warning_type, stacklevel=2)
# --> 604 return function(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/decorators.py:604, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     601             msg += f"\n        Use {alternative} instead."
#     602         warnings.warn(msg, warning_type, stacklevel=2)
# --> 604 return function(*args, **kwargs)
#
#     [... skipping similar frames: deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper at line 604 (2 times)]
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/decorators.py:604, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     601             msg += f"\n        Use {alternative} instead."
#     602         warnings.warn(msg, warning_type, stacklevel=2)
# --> 604 return function(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/ascii/ui.py:411, in read(table, guess, **kwargs)
#     405             new_kwargs["guess_html"] = _probably_html(table)
#     407 # Get the table from guess in ``dat``.  If ``dat`` comes back as None
#     408 # then there was just one set of kwargs in the guess list so fall
#     409 # through below to the non-guess way so that any problems result in a
#     410 # more useful traceback.
# --> 411 dat = _guess(table, new_kwargs, format, fast_reader)
#     412 if dat is None:
#     413     guess = False
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/ascii/ui.py:618, in _guess(table, read_kwargs, format, fast_reader)
#     615 reader = get_reader(**guess_kwargs)
#     617 reader.guessing = True
# --> 618 dat = reader.read(table)
#     619 _read_trace.append(
#     620     {
#     621         "kwargs": copy.deepcopy(guess_kwargs),
#    (...)
#     625     }
#     626 )
#     627 return dat
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/ascii/core.py:1414, in BaseReader.read(self, table)
#    1411     newline = None
#    1413 # Get a list of the lines (rows) in the table
# -> 1414 self.lines = self.inputter.get_lines(table, newline=newline)
#    1416 # Set self.data.data_lines to a slice of lines contain the data rows
#    1417 self.data.get_data_lines(self.lines)
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/io/ascii/core.py:335, in BaseInputter.get_lines(self, table, newline)
#     331 try:
#     332     if hasattr(table, "read") or (
#     333         "\n" not in table + "" and "\r" not in table + ""
#     334     ):
# --> 335         with get_readable_fileobj(table, encoding=self.encoding) as fileobj:
#     336             table = fileobj.read()
#     337     if newline is None:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/data.py:356, in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers, use_fsspec, fsspec_kwargs, close_files)
#     354 is_url = _is_url(name_or_obj)
#     355 if is_url:
# --> 356     name_or_obj = download_file(
#     357         name_or_obj,
#     358         cache=cache,
#     359         show_progress=show_progress,
#     360         timeout=remote_timeout,
#     361         sources=sources,
#     362         http_headers=http_headers,
#     363     )
#     364 fileobj = io.FileIO(name_or_obj, "r")
#     365 if is_url and not cache:
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/data.py:1529, in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1527 for source_url in sources:
#    1528     try:
# -> 1529         f_name = _download_file_from_source(
#    1530             source_url,
#    1531             timeout=timeout,
#    1532             show_progress=show_progress,
#    1533             cache=cache,
#    1534             remote_url=remote_url,
#    1535             pkgname=pkgname,
#    1536             http_headers=http_headers,
#    1537             ssl_context=ssl_context,
#    1538             allow_insecure=allow_insecure,
#    1539         )
#    1540         # Success!
#    1541         break
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/data.py:1313, in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1310         else:
#    1311             raise
# -> 1313 with _try_url_open(
#    1314     source_url,
#    1315     timeout=timeout,
#    1316     http_headers=http_headers,
#    1317     ftp_tls=ftp_tls,
#    1318     ssl_context=ssl_context,
#    1319     allow_insecure=allow_insecure,
#    1320 ) as remote:
#    1321     info = remote.info()
#    1322     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/astropy/utils/data.py:1227, in _try_url_open(source_url, timeout, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1224 req = urllib.request.Request(source_url, headers=http_headers)
#    1226 try:
# -> 1227     return urlopener.open(req, timeout=timeout)
#    1228 except urllib.error.URLError as exc:
#    1229     reason = exc.reason
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/urllib/request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# timeout: The read operation timed out
