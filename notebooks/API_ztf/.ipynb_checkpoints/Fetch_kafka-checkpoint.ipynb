# %% [markdown]
# **Fetching Kafka streams from Lasair**
#
# A simple program to fetch the results of a streaming query from Lasair. First we make sure the kafka consumer is installed.

# %%
# !pip install confluent_kafka
# !pip install lasair
from lasair import lasair_consumer
# Out:
# DEPRECATION: Loading egg at /Users/roywilliams/Library/Python/3.11/lib/python/site-packages/pyglet-2.0.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: confluent_kafka in /usr/local/lib/python3.11/site-packages (2.2.0)
# DEPRECATION: Loading egg at /Users/roywilliams/Library/Python/3.11/lib/python/site-packages/pyglet-2.0.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: lasair in /usr/local/lib/python3.11/site-packages (0.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from lasair) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (2022.12.7)

# %% [markdown]
# Here we choose the "Supernova candidate" query (https://lasair-iris.roe.ac.uk/query/2/), which identifies possible supernovae.

# %%
my_topic = 'lasair_2SN-likecandidates'

# %% [markdown]
# The group_id is how the server remembers what it has already sent. Here we use a random string, and thus start from the beginning each time. For continuous (daemon) consumption, the group_id should be a fixed string.

# %%
from random import randrange
group_id = 'test{}'.format(randrange(1000))
print('Using group_id', group_id)
# Out:
# Using group_id test420

# %%
consumer = lasair_consumer('kafka.lsst.ac.uk:9092', group_id, my_topic)

# %% [markdown]
# Now pick the first ten from the stream, convert the JSON to a python object, then convert it back to print.

# %%
import json
n = 0
while n < 10:
  msg = consumer.poll(timeout=20)
  if msg is None:
    break
  if msg.error():
    print(str(msg.error()))
    break
  jmsg = json.loads(msg.value())
  print(json.dumps(jmsg, indent=2))
  n += 1
# Out:
# {
#   "objectId": "ZTF23abjazdg",
#   "ramean": 336.1085913583333,
#   "decmean": -11.924132258333335,
#   "mjdmin": 60227.21094910009,
#   "mjdmax": 60244.152303200215,
#   "magrmin": 17.7878,
#   "rmag": 17.7878,
#   "classification": "SN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:50:58"
# }
# {
#   "objectId": "ZTF19aabkcch",
#   "ramean": 338.20332073333327,
#   "decmean": -20.373883186666664,
#   "mjdmin": 60216.16901620012,
#   "mjdmax": 60244.15277779987,
#   "magrmin": 18.2083,
#   "rmag": 18.4051,
#   "classification": "NT",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:50:58"
# }
# {
#   "objectId": "ZTF23ablgmvo",
#   "ramean": 339.21388535714283,
#   "decmean": -13.009048585714284,
#   "mjdmin": 60231.19072919991,
#   "mjdmax": 60244.152303200215,
#   "magrmin": 19.5579,
#   "rmag": 19.5579,
#   "classification": "SN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:51:15"
# }
# {
#   "objectId": "ZTF20ablkhtm",
#   "ramean": 327.0198246823529,
#   "decmean": -9.263541964705881,
#   "mjdmin": 60215.22811339982,
#   "mjdmax": 60244.150879600085,
#   "magrmin": 19.8231,
#   "rmag": 19.9983,
#   "classification": "NT",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:51:15"
# }
# {
#   "objectId": "ZTF18accpmtg",
#   "ramean": 327.2807241785714,
#   "decmean": -17.866480007142858,
#   "mjdmin": 60215.22858799994,
#   "mjdmax": 60244.16877309978,
#   "magrmin": 18.4174,
#   "rmag": 18.4174,
#   "classification": "SN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:51:15"
# }
# {
#   "objectId": "ZTF19aabjzsv",
#   "ramean": 341.3009754428571,
#   "decmean": -14.797820457142858,
#   "mjdmin": 60216.16901620012,
#   "mjdmax": 60244.15277779987,
#   "magrmin": 19.0298,
#   "rmag": 19.1004,
#   "classification": "SN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:51:15"
# }
# {
#   "objectId": "ZTF21abjvpsf",
#   "ramean": 326.9732969047619,
#   "decmean": -10.332353176190477,
#   "mjdmin": 60215.22811339982,
#   "mjdmax": 60244.172557900194,
#   "magrmin": 19.1565,
#   "rmag": 19.3566,
#   "classification": "SN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:53:02"
# }
# {
#   "objectId": "ZTF23aamshpi",
#   "ramean": 19.1338477,
#   "decmean": 24.319612152631578,
#   "mjdmin": 60215.21900459984,
#   "mjdmax": 60244.19189810008,
#   "magrmin": 14.1567,
#   "rmag": 14.1942,
#   "classification": "ORPHAN",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:53:19"
# }
# {
#   "objectId": "ZTF19abdkaon",
#   "ramean": 335.85920997999995,
#   "decmean": -22.756730893333334,
#   "mjdmin": 60220.29025459988,
#   "mjdmax": 60244.169722199906,
#   "magrmin": 18.9248,
#   "rmag": 18.9248,
#   "classification": "NT",
#   "score": "Not Near PS1 star",
#   "UTC": "2023-10-27 16:53:19"
# }
# {
#   "objectId": "ZTF19abiqifg",
#   "ramean": 351.10682008,
#   "decmean": -21.680758466666664,
#   "mjdmin": 60221.2426967998,
#   "mjdmax": 60244.19025459979,
#   "magrmin": 17.8897,
#   "rmag": 17.8948,
#   "classification": "NT",
#   "score": "Within 2arcsec of PS1 star",
#   "UTC": "2023-10-27 16:59:57"
# }
# %4|1699542073.731|MAXPOLL|rdkafka#consumer-1| [thrd:main]: Application maximum poll interval (300000ms) exceeded by 426ms (adjust max.poll.interval.ms for long-running message processing): leaving group
# %3|1699578088.698|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Receive failed: Operation timed out (after 36315789ms in state UP)
# %3|1699578119.708|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30004ms in state CONNECT)
# %4|1699578119.708|METADATA|rdkafka#consumer-1| [thrd:main]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Metadata request failed: periodic topic and broker list refresh: Local: Host resolution failure (0ms): Permanent
# %5|1699578149.386|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1001: Timed out MetadataRequest in flight (after 60688ms, timeout #0)
# %5|1699578149.387|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1001: Timed out MetadataRequest in flight (after 60216ms, timeout #1)
# %4|1699578149.387|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1001: Timed out 2 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1699578149.387|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092
FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579225.631|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30001ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579227.360|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579228.360|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579256.636|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579258.525|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579259.528|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30000ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579287.648|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579289.697|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579290.704|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30004ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579318.655|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579320.925|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30001ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579321.929|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30001ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579349.665|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579352.073|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30005ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579353.072|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579380.675|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30001ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579383.231|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579384.184|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579411.688|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579414.430|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579415.440|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579442.700|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579445.593|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579446.596|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579473.707|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579476.787|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579477.795|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30002ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579504.716|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579507.963|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579508.971|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 30003ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1699579537.235|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 9ms in state CONNECT, 9 identical error(s) suppressed)
# %3|1699579539.349|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579539.437|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579569.473|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1699579569.714|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 0ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579573.053|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579600.676|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579601.679|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579603.068|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579631.530|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 0ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579632.885|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579640.886|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579663.027|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1699579664.035|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579670.905|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579693.217|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 18ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1699579694.202|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579709.291|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579723.385|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579724.392|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1699579739.314|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579754.571|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579754.673|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579769.334|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579784.708|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1699579786.733|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579799.351|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579814.741|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 14 identical error(s) suppressed)
# %3|1699579816.896|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579835.559|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579845.074|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579848.084|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579873.220|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579877.251|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1699579878.257|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1699579907.440|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1699579908.447|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1699579909.377|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1699579938.625|FAIL|rdkafka#consumer-1| [thrd:lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001]: lasair-ztf-kafka_pub.lsst.ac.uk:9092/1001: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1699579939.397|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: lasair-ztf-kafka_pub.lsst.ac.uk:9092: Failed to resolve 'lasair-ztf-kafka_pub.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1699579939.398|FAIL|rdkafka#consumer-1| [thrd:kafka.lsst.ac.uk:9092/bootstrap]: kafka.lsst.ac.uk:9092/bootstrap: Failed to resolve 'kafka.lsst.ac.uk:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 17 identical error(s) suppressed)
