# %%
# %run ShowCutouts.ipynb

# %%
sciUrl='https://lasair-ztf.lsst.ac.uk/lasair/static/fits/60203/4f0/2449485570615015012_cutoutScience.fits'
temUrl='https://lasair-ztf.lsst.ac.uk/lasair/static/fits/60203/868/2449485570615015012_cutoutTemplate.fits'

# %%
fig, axs = plt.subplots(ncols=2, figsize=(8, 3), 
gridspec_kw={'width_ratios': [1, 1]})
    
show_fits(
    axs[0], temUrl,
    axs[1], sciUrl,
)
# Out:
# WARNING: VerifyWarning: Found a SIMPLE card but its format doesn't respect the FITS Standard [astropy.io.fits.hdu.hdulist]
