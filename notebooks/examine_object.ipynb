# %% [markdown]
# ## Examine an Object
#
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html
#
# Below is the ID for the object you wish to examine:

# %%
diaObjectId = 313761043604045880

# %%
import os, sys, time, json
from lasair import LasairError, lasair_client as lasair

API_TOKEN = os.getenv('LASAIR_LSST_TOKEN')
if API_TOKEN is None:
    print("No Token found. Check Spelling. Note that if you have just added your token to your environment variables, you may need to restart your terminal so your shell settings are reloaded. ")

# %%
endpoint = "https://api.lasair.lsst.ac.uk/api"
L = lasair(API_TOKEN, endpoint=endpoint)

# %%
# This function summarizes the JSON output. You can use normal print() of course 
# but there may be a large amount of output.
def printobj(name, obj, indent=''):
    if indent=='':
        print('Size of object is ', len(json.dumps(obj)), 'bytes')
    if isinstance(obj, list):
        print('%s%s is a list of %d items' % (indent, name, len(obj)))
        if len(obj) > 0:
            printobj(name+'[0]', obj[0], indent=indent+'  ')
    elif isinstance(obj, dict):
        kks = list(obj.keys())
        if len(kks) > 5:
            print('%s%s is a dict of %d items, first 5 are' % (indent, name, len(kks)))
            kks = kks[:5]
        else:
            print('%s%s is a dict of %d items' % (indent, name, len(kks)))
        for kk in kks[:5]:
            printobj(kk, obj[kk], indent=indent+'  ')
    else:
        print('%s%s: %s' % (indent, name, obj))

# %%
obj = L.object(diaObjectId, lasair_added=True, lite=False)
dobj = obj['diaObject']

# %% [markdown]
# ## Key-Value dictionary

# %%
print('object position is %.5f, %.5f' % (dobj['ra'], dobj['decl']))
print('MJD of first and last detections %.4f, %.4f' % (dobj['firstDiaSourceMjdTai'], dobj['lastDiaSourceMjdTai']))

for k, v in obj['lasairData'].items():
    if k != 'sherlock' and k != 'imageUrls' and k != 'TNS' and k != 'annotations':
        print(k, ':', v)
# Out:
# object position is 61.96482, -48.71344
# MJD of first and last detections 61003.3367, 61102.1195
# diaObjectId : 313761043604045880
# lastDiaSourceMjdTai : 61102.11949211106
# firstDiaSourceMjdTai : 61003.336679130254
# latest_psfFlux : 128157.0
# u_psfFlux : None
# u_latestMJD : None
# u_psfFluxMean : None
# u_psfFluxMeanErr : None
# g_psfFlux : 46678.5
# g_latestMJD : 61019.3
# g_psfFluxMean : None
# g_psfFluxMeanErr : None
# r_psfFlux : 1007.56
# r_latestMJD : 61003.3
# r_psfFluxMean : None
# r_psfFluxMeanErr : None
# i_psfFlux : -18166.0
# i_latestMJD : 61006.2
# i_psfFluxMean : None
# i_psfFluxMeanErr : None
# z_psfFlux : 10340.0
# z_latestMJD : 61009.1
# z_psfFluxMean : 117113.0
# z_psfFluxMeanErr : 44.928
# y_psfFlux : None
# y_latestMJD : None
# y_psfFluxMean : None
# y_psfFluxMeanErr : None
# medianR : 1.0
# latestR : 1.0
# nDiaSources : 657
# nSourcesGood : 656
# nuSources : 0
# ngSources : 132
# nrSources : 167
# niSources : 202
# nzSources : 156
# nySources : 0
# tns_name : 2025agpz
# absMag : None
# absMagMJD : None
# BBBRiseRate : 0.00966359
# BBBFallRate : None
# BBBTemp : 6.0429
# BBBPeakFlux : None
# BBBPeakMJD : None
# BBBPeakAbsMag : None
# glat : -46.6423
# ebv : 0.0127092
# jump1 : 1.81106
# jump2 : 0.644267
# latestPairMJD : 61100.1
# latestPairColourMag : 0.164238
# latestPairColourBands : r-z
# latestPairColourTemp : 5.92821
# penultimatePairMJD : 61099.0
# penultimatePairColourMag : 0.405948
# penultimatePairColourBands : g-i
# penultimatePairColourTemp : 6.15588
# htm16 : 37737915309
# timestamp : 2026-03-03T02:55:32
# validityStartMjdTai : 61102.12111371617
# raErr : 3.13684e-05
# decErr : 5.67411e-05
# ra_dec_Cov : 3.1585e-10
# u_psfFluxSigma : None
# u_psfFluxNdata : 0
# u_fpFluxMean : None
# u_fpFluxMeanErr : None
# g_psfFluxSigma : None
# g_psfFluxNdata : 0
# g_fpFluxMean : None
# g_fpFluxMeanErr : None
# r_psfFluxSigma : None
# r_psfFluxNdata : 0
# r_fpFluxMean : None
# r_fpFluxMeanErr : None
# i_psfFluxSigma : None
# i_psfFluxNdata : 0
# i_fpFluxMean : None
# i_fpFluxMeanErr : None
# z_psfFluxSigma : 27964.6
# z_psfFluxNdata : 156
# z_fpFluxMean : None
# z_fpFluxMeanErr : None
# y_psfFluxSigma : None
# y_psfFluxNdata : 0
# y_fpFluxMean : None
# y_fpFluxMeanErr : None
# u_scienceFluxMean : None
# u_scienceFluxMeanErr : None
# g_scienceFluxMean : None
# g_scienceFluxMeanErr : None
# r_scienceFluxMean : None
# r_scienceFluxMeanErr : None
# i_scienceFluxMean : None
# i_scienceFluxMeanErr : None
# z_scienceFluxMean : 125105.0
# z_scienceFluxMeanErr : 45.5909
# y_scienceFluxMean : None
# y_scienceFluxMeanErr : None
# u_psfFluxMin : None
# u_psfFluxMax : None
# u_psfFluxMaxSlope : None
# u_psfFluxErrMean : None
# g_psfFluxMin : None
# g_psfFluxMax : None
# g_psfFluxMaxSlope : None
# g_psfFluxErrMean : None
# r_psfFluxMin : None
# r_psfFluxMax : None
# r_psfFluxMaxSlope : None
# r_psfFluxErrMean : None
# i_psfFluxMin : None
# i_psfFluxMax : None
# i_psfFluxMaxSlope : None
# i_psfFluxErrMean : None
# z_psfFluxMin : 8828.53
# z_psfFluxMax : 133318.0
# z_psfFluxMaxSlope : 4706660.0
# z_psfFluxErrMean : 567.002
# y_psfFluxMin : None
# y_psfFluxMax : None
# y_psfFluxMaxSlope : None
# y_psfFluxErrMean : None
# rasex : 04:07:51.557
# decsex : -48:42:48.396
# ec_lon : 37.20538602905405
# ec_lat : -67.08436801846764
# g_lon : 256.3391147031928
# g_lat : -46.642267810222314
# now_mjd : 61102.46
# mjdmin_ago : 99.1184550753751
# mjdmax_ago : 0.3356420945710852
# discMjd : 61003.336679130254
# discUtc : 2025-11-24 08:04:49
# discMag : 1007.56±170.88
# discFilter : r
# latestMjd : 61102.11949211106
# latestUtc : 2026-03-03 02:52:04
# latestMag : 128156.91±868.86
# latestFilter : r
# peakMjd : 61090.09003633589
# peakUtc : 2026-02-19 02:09:39
# peakMag : 133318.11±620.39
# peakFilter : z

# %% [markdown]
# ## Sherlock data

# %%
print(json.dumps(obj['lasairData']['sherlock'], indent=2))
# Out:
# {
#   "diaObjectId": 313761043604045880,
#   "classification": "SN",
#   "association_type": "SN",
#   "catalogue_table_name": "DESI",
#   "catalogue_object_id": "10000,82215,16929",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 61.964776070572746,
#   "decDeg": -48.713435745556154,
#   "separationArcsec": 0.055,
#   "northSeparationArcsec": -0.00251166,
#   "eastSeparationArcsec": -0.0555143,
#   "physical_separation_kpc": null,
#   "direct_distance": null,
#   "distance": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "Mag": 23.746,
#   "MagFilter": "r",
#   "MagErr": 0.054,
#   "classificationReliability": 2,
#   "major_axis_arcsec": null,
#   "annotator": "https://github.com/thespacedoctor/sherlock/releases/tag/v3.1.0",
#   "additional_output": "http://lasair-lsst.lsst.ac.uk/api/sherlock/object/313761043604045880",
#   "description": "The transient is possibly associated with <em>10000,82215,16929</em>; an r=23.75 mag galaxy found in the DESI catalogue. Its located 0.00\" N, 0.06\" E from the galaxy centre.",
#   "summary": null
# }

# %% [markdown]
# ## imageUrls
# (first three only)

# %%
print(json.dumps(obj['lasairData']['imageUrls'][:3], indent=2))
# Out:
# [
#   {
#     "Science": "https://lasair.lsst.ac.uk/fits/170081276982722562_cutoutScience",
#     "Template": "https://lasair.lsst.ac.uk/fits/170081276982722562_cutoutTemplate",
#     "Difference": "https://lasair.lsst.ac.uk/fits/170081276982722562_cutoutDifference",
#     "diaSourceId": 170081276982722562
#   },
#   {
#     "Science": "https://lasair.lsst.ac.uk/fits/170081276720054325_cutoutScience",
#     "Template": "https://lasair.lsst.ac.uk/fits/170081276720054325_cutoutTemplate",
#     "Difference": "https://lasair.lsst.ac.uk/fits/170081276720054325_cutoutDifference",
#     "diaSourceId": 170081276720054325
#   },
#   {
#     "Science": "https://lasair.lsst.ac.uk/fits/170081276595798018_cutoutScience",
#     "Template": "https://lasair.lsst.ac.uk/fits/170081276595798018_cutoutTemplate",
#     "Difference": "https://lasair.lsst.ac.uk/fits/170081276595798018_cutoutDifference",
#     "diaSourceId": 170081276595798018
#   }
# ]

# %% [markdown]
# ## TNS data

# %%
print(json.dumps(obj['lasairData']['TNS'], indent=2))
# Out:
# {
#   "ra": 61.964865,
#   "decl": -48.713235,
#   "tns_name": "2025agpz",
#   "tns_prefix": "AT",
#   "disc_mag": 19.739,
#   "disc_mag_filter": "cyan",
#   "disc_int_name": "ATLAS25pny",
#   "disc_date": "10th December 2025 at 21:37:31",
#   "disc_date_mjd": 61019.90106,
#   "lastmodified_date": "13th December 2025 at 08:37:35",
#   "lastmodified_date_mjd": 61022.35943287037,
#   "sender": "ATLAS",
#   "reporters": "J. Tonry, L. Denneau, H. Weiland (IfA, University of Hawaii), N. Erasmus, W...",
#   "source_group": "ATLAS",
#   "htm16": 37737915309,
#   "lasairmodified_date": "24th February 2026 at 09:29:35",
#   "lasairmodified_date_mjd": 61095.39554398148,
#   "id": 37380,
#   "diaObjectId": 313761043604045880,
#   "wl_id": 46,
#   "cone_id": 5689113,
#   "arcsec": 0.758,
#   "name": "2025agpz"
# }

# %% [markdown]
# ## Annotations

# %%
for a in obj['lasairData']['annotations']:
    for k,v in a.items():
        print(k, ':', v)
# Out:
# annotationID : 1009865
# topic : r0b_lvra
# version : a1
# timestamp : 2026-03-03 03:00:32
# classification : 0.9583158780350394
# explanation : r0b - Real Or Bogus Classifier
# classdict : {"blame_diaSourceId": "170081276982722562", "n_gt22": 653, "n_gt21": 649, "n_gt20": 645, "n_gt19": 445, "n_gt18": 0, "brighter22": 1, "brighter21": 1, "brighter20": 1, "brighter19": 1, "brighter18": 0, "first22": 0, "first21": 0, "first20": 0, "first19": 0, "first18": 0, "model_version": "a1", "provenance_ID": "249277", "stem": "20260303_030001"}
# url : https://lasairvras.github.io/lvra-doc/r0b.html

# %%
### Plot a Lightcurve
Plot the diaSources and the diaForcedSources
# Out:
#   Cell In[11], line 2
#     Plot the diaSources and the diaForcedSources
#          ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
color    = {'u':"#9900cc", 'g':"#3366ff", 'r':"#33cc33", 'i':"#ffcc00", 'z':"#ff0000", 'y':"#cc6600"}
fig = plt.figure(figsize=(6,4))
ax = plt.subplot(1, 1, 1)
ax.set_yscale('log')

for band in color.keys():
    # plot the sources
    tb = []
    fb = []
    fberr = []
    for s in obj['diaSourcesList']:
        if s['band'] == band:
            tb   .append(s['midpointMjdTai'])
            fb   .append(s['psfFlux'])
            fberr.append(s['psfFluxErr'])
    ax.errorbar(tb, fb, yerr=fberr, fmt='o', color=color[band], label=band)
    
    # plot the forced sources
    tb = []
    fb = []
    fberr = []
    for s in obj['diaForcedSourcesList']:
        if s['band'] == band:
            tb   .append(s['midpointMjdTai'])
            fb   .append(s['psfFlux'])
            fberr.append(s['psfFluxErr'])
    ax.errorbar(tb, fb, yerr=fberr, fmt='x', color=color[band])
    
plt.title(obj['diaObjectId'])
plt.xlabel("MJD")
plt.ylabel("Flux")
plt.show()
