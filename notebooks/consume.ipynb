# %% [markdown]
# # Test notebook to exercise the alert consumers
# ### To run this notebook, please [follow the instructions](https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html) or else it won`t work.
# The instructions are at https://lasair-lsst.readthedocs.io/en/main/core_functions/python-notebooks.html

# %%
import sys, time, json
from lasair import lasair_consumer

# %% [markdown]
# ## Normal Consumer

# %%
kafka_server = 'lasair-lsst-kafka.lsst.ac.uk:9092'   # prod
topic        = "lasair_1Lightweight"    # prod

# %%
group_id     = 'test127'
consumer = lasair_consumer(
    kafka_server,    
    group_id,        # any string
    topic            # topic name for your filter
)

n = 0
while n < 10:
    msg = consumer.poll(timeout=5)
    if msg is None:
        print('sleeping 5')
        time.sleep(5)
        continue
    if msg.error():
        print(str(msg.error()))
        break
    jmsg = json.loads(msg.value())
    print(json.dumps(jmsg, indent=2))
    n += 1
print('No more messages available')
# Out:
# {
#   "diaObjectId": 313637935709683761,
#   "ra": 61.62227592104076,
#   "decl": -49.29512529953388,
#   "lastDiaSourceMjdTai": 60985.2486417264,
#   "firstDiaSourceMjdTai": 60975.20468840409,
#   "nDiaSources": 7,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313637935744286779,
#   "ra": 57.43050153648073,
#   "decl": -48.562874197289446,
#   "lastDiaSourceMjdTai": 60984.23132443137,
#   "firstDiaSourceMjdTai": 60975.20468840409,
#   "nDiaSources": 2,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313637935750578248,
#   "ra": 59.394556117353254,
#   "decl": -49.52238282689945,
#   "lastDiaSourceMjdTai": 60985.248201620954,
#   "firstDiaSourceMjdTai": 60975.20468840409,
#   "nDiaSources": 2,
#   "classification": "VS",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664312457036338,
#   "ra": 64.84874655325703,
#   "decl": -46.35387730532457,
#   "lastDiaSourceMjdTai": 60981.27640793739,
#   "firstDiaSourceMjdTai": 60981.27596997942,
#   "nDiaSources": 2,
#   "classification": "VS",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664312719705002,
#   "ra": 65.57140338516311,
#   "decl": -48.618067545860626,
#   "lastDiaSourceMjdTai": 60981.27735085849,
#   "firstDiaSourceMjdTai": 60981.27691396534,
#   "nDiaSources": 2,
#   "classification": "VS",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664312957206554,
#   "ra": 64.50844526049833,
#   "decl": -48.16220235821823,
#   "lastDiaSourceMjdTai": 60985.24912577815,
#   "firstDiaSourceMjdTai": 60981.277865211654,
#   "nDiaSources": 7,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664312967168019,
#   "ra": 62.966200109686184,
#   "decl": -47.64869503303249,
#   "lastDiaSourceMjdTai": 60984.23228399,
#   "firstDiaSourceMjdTai": 60981.277865211654,
#   "nDiaSources": 5,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664312969789443,
#   "ra": 63.13689894221817,
#   "decl": -47.99477636621044,
#   "lastDiaSourceMjdTai": 60981.27830127439,
#   "firstDiaSourceMjdTai": 60981.277865211654,
#   "nDiaSources": 2,
#   "classification": "VS",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664313102958614,
#   "ra": 62.54689128635844,
#   "decl": -47.74933055119898,
#   "lastDiaSourceMjdTai": 60984.23228399,
#   "firstDiaSourceMjdTai": 60981.27830127439,
#   "nDiaSources": 3,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# {
#   "diaObjectId": 313664313300090962,
#   "ra": 61.976004004312564,
#   "decl": -47.73827269404566,
#   "lastDiaSourceMjdTai": 60987.28089645611,
#   "firstDiaSourceMjdTai": 60981.278783090966,
#   "nDiaSources": 18,
#   "classification": "SN",
#   "UTC": "2026-02-14 13:41:02"
# }
# No more messages available
