# %%
import json

# %% [markdown]
# ### The alert packet sent through the Lasair system
# The 3 cutout images have been removed, and the remainder converted to JSON.
# Instead of a latest thing and list of previous things, we just have a list of things:
# `diaSource` and `prvDiaSources` becomes `diaSourcesList`.

# %%
with open('json/diaObject.json') as f:
    obj = json.loads(f.read())
print(json.dumps(obj, indent=2))
# Out:
# {
#   "diaObjectId": 3068394709727576424,
#   "ra": 280.841661337863,
#   "raErr": 1.0818514056154527e-05,
#   "decl": -48.04938167797351,
#   "decErr": 2.3659385988139547e-05,
#   "ra_dec_Cov": -1.260528348367984e-10,
#   "radecMjdTai": 60487.399151209436,
#   "pmRa": null,
#   "pmRaErr": null,
#   "pmDec": null,
#   "pmDecErr": null,
#   "parallax": null,
#   "parallaxErr": null,
#   "pmRa_pmDec_Cov": null,
#   "pmRa_parallax_Cov": null,
#   "pmDec_parallax_Cov": null,
#   "pmParallaxLnL": null,
#   "pmParallaxChi2": null,
#   "pmParallaxNdata": 0,
#   "u_psfFluxMean": null,
#   "u_psfFluxMeanErr": null,
#   "u_psfFluxSigma": null,
#   "u_psfFluxChi2": null,
#   "u_psfFluxNdata": 0,
#   "u_fpFluxMean": null,
#   "u_fpFluxMeanErr": null,
#   "u_fpFluxSigma": null,
#   "g_psfFluxMean": null,
#   "g_psfFluxMeanErr": null,
#   "g_psfFluxSigma": null,
#   "g_psfFluxChi2": null,
#   "g_psfFluxNdata": 0,
#   "g_fpFluxMean": null,
#   "g_fpFluxMeanErr": null,
#   "g_fpFluxSigma": null,
#   "r_psfFluxMean": 11240.3251953125,
#   "r_psfFluxMeanErr": 828.338623046875,
#   "r_psfFluxSigma": null,
#   "r_psfFluxChi2": 0.0,
#   "r_psfFluxNdata": 1,
#   "r_fpFluxMean": null,
#   "r_fpFluxMeanErr": null,
#   "r_fpFluxSigma": null,
#   "i_psfFluxMean": null,
#   "i_psfFluxMeanErr": null,
#   "i_psfFluxSigma": null,
#   "i_psfFluxChi2": null,
#   "i_psfFluxNdata": 0,
#   "i_fpFluxMean": null,
#   "i_fpFluxMeanErr": null,
#   "i_fpFluxSigma": null,
#   "z_psfFluxMean": null,
#   "z_psfFluxMeanErr": null,
#   "z_psfFluxSigma": null,
#   "z_psfFluxChi2": null,
#   "z_psfFluxNdata": 0,
#   "z_fpFluxMean": null,
#   "z_fpFluxMeanErr": null,
#   "z_fpFluxSigma": null,
#   "y_psfFluxMean": null,
#   "y_psfFluxMeanErr": null,
#   "y_psfFluxSigma": null,
#   "y_psfFluxChi2": null,
#   "y_psfFluxNdata": 0,
#   "y_fpFluxMean": null,
#   "y_fpFluxMeanErr": null,
#   "y_fpFluxSigma": null,
#   "nearbyObj1": 0,
#   "nearbyObj1Dist": null,
#   "nearbyObj1LnP": null,
#   "nearbyObj2": 0,
#   "nearbyObj2Dist": null,
#   "nearbyObj2LnP": null,
#   "nearbyObj3": 0,
#   "nearbyObj3Dist": null,
#   "nearbyObj3LnP": null,
#   "u_psfFluxErrMean": null,
#   "g_psfFluxErrMean": null,
#   "r_psfFluxErrMean": 828.338623046875,
#   "i_psfFluxErrMean": null,
#   "z_psfFluxErrMean": null,
#   "y_psfFluxErrMean": null
# }

# %%
with open('json/diaSource.json') as f:
    src = json.loads(f.read())
print(json.dumps(src, indent=2))
# Out:
# {
#   "diaSourceId": 3068394727981187617,
#   "visit": 7024062500766,
#   "detector": 0,
#   "diaObjectId": 3068394709727576424,
#   "ssObjectId": 0,
#   "parentDiaSourceId": 0,
#   "midpointMjdTai": 60487.399151209436,
#   "ra": 280.84167172238614,
#   "raErr": 5.224281721893931e-06,
#   "decErr": 7.89316891314229e-06,
#   "ra_dec_Cov": 4.372064342506032e-12,
#   "x": 955.6641845703125,
#   "xErr": null,
#   "y": 1136.1016845703125,
#   "yErr": null,
#   "x_y_Cov": null,
#   "centroid_flag": false,
#   "apFlux": -14048.7373046875,
#   "apFluxErr": 1254.7178955078125,
#   "apFlux_flag": false,
#   "apFlux_flag_apertureTruncated": false,
#   "snr": 14.663597106933594,
#   "psfFlux": 11240.3251953125,
#   "psfFluxErr": 828.338623046875,
#   "psfRa": null,
#   "psfRaErr": null,
#   "psfDec": null,
#   "psfDecErr": null,
#   "psfFlux_psfRa_Cov": null,
#   "psfFlux_psfDec_Cov": null,
#   "psfRa_psfDec_Cov": null,
#   "psfLnL": null,
#   "psfChi2": 3021.782958984375,
#   "psfNdata": 1681,
#   "psfFlux_flag": false,
#   "psfFlux_flag_edge": false,
#   "psfFlux_flag_noGoodPixels": false,
#   "trailFlux": -18588.7578125,
#   "trailFluxErr": null,
#   "trailRa": 280.8421236190729,
#   "trailRaErr": null,
#   "trailDec": -48.04937735141933,
#   "trailDecErr": null,
#   "trailLength": 1.6215460300445557,
#   "trailLengthErr": null,
#   "trailAngle": -168.0467987060547,
#   "trailAngleErr": null,
#   "trailFlux_trailRa_Cov": null,
#   "trailFlux_trailDec_Cov": null,
#   "trailFlux_trailLength_Cov": null,
#   "trailDec_trailAngle_Cov": null,
#   "trailLength_trailAngle_Cov": null,
#   "trailLnL": null,
#   "trailChi2": null,
#   "trailNdata": 0,
#   "trail_flag_edge": false,
#   "dipoleMeanFlux": 957974.0625,
#   "dipoleMeanFluxErr": 479040.46875,
#   "dipoleFluxDiff": 0.0,
#   "dipoleFluxDiffErr": 5301.17724609375,
#   "dipoleRa": null,
#   "dipoleRaErr": null,
#   "dipoleDec": null,
#   "dipoleDecErr": null,
#   "dipoleLength": 0.015040887519717216,
#   "dipoleLengthErr": null,
#   "dipoleAngle": -73.0124282836914,
#   "dipoleAngleErr": null,
#   "dipoleMeanFlux_dipoleFluxDiff_Cov": null,
#   "dipoleMeanFlux_dipoleRa_Cov": null,
#   "dipoleMeanFlux_dipoleDec_Cov": null,
#   "dipoleMeanFlux_dipoleLength_Cov": null,
#   "dipoleMeanFlux_dipoleAngle_Cov": null,
#   "dipoleFluxDiff_dipoleRa_Cov": null,
#   "dipoleFluxDiff_dipoleDec_Cov": null,
#   "dipoleFluxDiff_dipoleLength_Cov": null,
#   "dipoleFluxDiff_dipoleAngle_Cov": null,
#   "dipoleRa_dipoleDec_Cov": null,
#   "dipoleRa_dipoleLength_Cov": null,
#   "dipoleRa_dipoleAngle_Cov": null,
#   "dipoleDec_dipoleLength_Cov": null,
#   "dipoleDec_dipoleAngle_Cov": null,
#   "dipoleLength_dipoleAngle_Cov": null,
#   "dipoleLnL": null,
#   "dipoleChi2": 2726.3125,
#   "dipoleNdata": 2976,
#   "forced_PsfFlux_flag": false,
#   "forced_PsfFlux_flag_edge": false,
#   "forced_PsfFlux_flag_noGoodPixels": false,
#   "snapDiffFlux": null,
#   "snapDiffFluxErr": null,
#   "fpBkgd": null,
#   "fpBkgdErr": null,
#   "ixx": 0.3029245138168335,
#   "ixxErr": null,
#   "iyy": 0.15458641946315765,
#   "iyyErr": null,
#   "ixy": -0.12886685132980347,
#   "ixyErr": null,
#   "ixx_iyy_Cov": null,
#   "ixx_ixy_Cov": null,
#   "iyy_ixy_Cov": null,
#   "ixxPSF": 0.194138303399086,
#   "iyyPSF": 0.0026660976000130177,
#   "ixyPSF": 0.0026660976000130177,
#   "shape_flag": false,
#   "shape_flag_no_pixels": false,
#   "shape_flag_not_contained": false,
#   "shape_flag_parent_source": false,
#   "extendedness": null,
#   "reliability": null,
#   "band": "r",
#   "pixelFlags": false,
#   "pixelFlags_bad": false,
#   "pixelFlags_cr": false,
#   "pixelFlags_crCenter": false,
#   "pixelFlags_edge": false,
#   "pixelFlags_interpolated": false,
#   "pixelFlags_interpolatedCenter": false,
#   "pixelFlags_offimage": false,
#   "pixelFlags_saturated": false,
#   "pixelFlags_saturatedCenter": false,
#   "pixelFlags_suspect": false,
#   "pixelFlags_suspectCenter": false,
#   "pixelFlags_streak": false,
#   "pixelFlags_streakCenter": false,
#   "pixelFlags_injected": false,
#   "pixelFlags_injectedCenter": false,
#   "pixelFlags_injected_template": false,
#   "pixelFlags_injected_templateCenter": false,
#   "decl": -48.04927420332769
# }

# %%
with open('json/diaForcedSource.json') as f:
    fsrc = json.loads(f.read())
print(json.dumps(fsrc, indent=2))
# Out:
# {
#   "diaForcedSourceId": 3068394727981195731,
#   "diaObjectId": 3068394709727576424,
#   "ra": 4.901611667116573,
#   "visit": 7024062500766,
#   "detector": 0,
#   "psfFlux": 7962.67041015625,
#   "psfFluxErr": 830.54638671875,
#   "midpointMjdTai": 60487.399151209436,
#   "band": "r",
#   "decl": -0.8386199138280754
# }

# %%
with open('json/99999999999.json') as f:
    alert = json.loads(f.read())

# %%
import matplotlib.pyplot as plt
color    = {
    'u':"#9900cc",     
    'g':"#3366ff",     
    'r':"#33cc33",     
    'i':"#ffcc00",     
    'z':"#ff0000",     
    'y':"#cc6600", 
}
fig = plt.figure(figsize=(6,4))
ax = plt.subplot(1, 1, 1)
ax.set_yscale('log')
     
for band in color.keys():
    tb = []
    fb = []
    fberr = []
    for s in alert['diaSourcesList']:
        if s['band'] == band:
            tb   .append(s['midpointMjdTai'])
            fb   .append(s['psfFlux'])
            fberr.append(s['psfFluxErr'])
    ax.errorbar(tb, fb, yerr=fberr, fmt='o', color=color[band], label=band)   
plt.title(alert['diaObject']['diaObjectId'])
plt.show()

# %% [markdown]
# ## Filtering objects

# %% [markdown]
# ### Things in SQL filters
# These attributes are computed or copied from the alert packet, and are available in the schema browser to be used as the SELECT or WHERE clauses of a Lasair filter.
# ```
#               diaObjectId: ID for this object
#                        ra: Mean RA of this object
#                      decl: Mean Dec of this object
#               radecMjdTai: Time at which the object was at a position ra/dec ()
#
#                      pmRa: Proper motion in right ascension (mas/yr)
#                     pmDec: Proper motion in declination (mas/yr)
#
#                 u_psfFlux: Latest u flux (nJy)
#             u_psfFluxMean: Weighted mean point-source model magnitude for u filter. (nJy)
#          u_psfFluxMeanErr: Standard error of u_psfFluxMean. (nJy)
#                 g_psfFlux: Latest g flux (nJy)
#             g_psfFluxMean: Weighted mean point-source model magnitude for g filter. (nJy)
#          g_psfFluxMeanErr: Standard error of g_psfFluxMean. (nJy)
#                 r_psfFlux: Latest r flux (nJy)
#             r_psfFluxMean: Weighted mean point-source model magnitude for r filter. (nJy)
#          r_psfFluxMeanErr: Standard error of r_psfFluxMean. (nJy)
#                 i_psfFlux: Latest i flux (nJy)
#             i_psfFluxMean: Weighted mean point-source model magnitude for i filter. (nJy)
#          i_psfFluxMeanErr: Standard error of i_psfFluxMean. (nJy)
#                 z_psfFlux: Latest z flux (nJy)
#             z_psfFluxMean: Weighted mean point-source model magnitude for z filter. (nJy)
#          z_psfFluxMeanErr: Standard error of z_psfFluxMean. (nJy)
#                 y_psfFlux: Latest y flux (nJy)
#             y_psfFluxMean: Weighted mean point-source model magnitude for y filter. (nJy)
#          y_psfFluxMeanErr: Standard error of y_psfFluxMean. (nJy)
#
#                  nSources: Number of diaSources associated with this diaObject
#                 nuSources: Number of u sources
#                 ngSources: Number of u sources
#                 nrSources: Number of u sources
#                 niSources: Number of u sources
#                 nzSources: Number of u sources
#                 nySources: Number of u sources
#
#                    maxTai: Latest MJD of a diaSource
#                    minTai: Earliest MJD of a diaSource
#
#             nearbyExtObj1: Id of the closest extended DR Object by second moment-based separation.
#          nearbyExtObj1Sep: Second moment-based separation of nearbyExtObj1 (unitless).
#                nearbyObj1: Id of the closest nearby object.
#            nearbyObj1Dist: Distance to nearbyObj1 (arcsec)
#             nearbyObj1LnP: Natural log of the probability that the observed diaObject is the same as the nearbyObj1.
#             nearbyLowzGal: External catalog name of the nearest low-z potential host.
#          nearbyLowzGalSep: Separation distance of nearbyLowzGal. (arcsc)
#                nearbyObj1: Id of the closest nearby object. ()
#            nearbyObj1Dist: Distance to nearbyObj1. (arcsec)
#             nearbyObj1LnP: Natural log of the probability that the observed diaObject is the same as the nearbyObj1. ()
#
#                    absMag: Most recent absolute magnitude if host galaxy with distance available
#
#               BBBRiseRate: Fitted Bazin or Exp rise rate
#               BBBFallRate: Fitted Bazin or Exp fall rate
#                   BBBTemp: Fitted Bazin temperature, kiloKelvins
#
#                      glat: Galactic latitude
#                       ebv: Extinction E(B-V) Schlegel, Finkbeiner & Davis (1998)
#
#              mean10change: p-value for change of mean brightness: last 10 days versus 10 before that
#              mean20change: p-value for change of mean brightness: last 20 days versus 20 before that
#
#        latest_revisit_mjd: Latest revisit MJD
# latest_revisit_colour_mag: Magnitude difference from latest revisit
# latest_revisit_colour_bands: Bands used for revisit colour, eg g-r, u-r
# latest_revisit_colour_temp: Extinction corrected effective temperature from latest revisit, kiloKelvin
#
#                    period: Estimate of period (or NULL)
#            period_entropy: Quality of period estimate (lower is better)
# ```
