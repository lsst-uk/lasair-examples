# %% [markdown]
# # Sherlock (Context Classification)
# ### Ken Smith
# The Sherlock service gives the context of a list of objects in the sky based on numerous large catalogues (e.g. Pan-STARRS1, Gaia DR2, etc.).  The service can also accept an arbitrary position in the sky.
#
# Demonstrates usage of:
# * /streams/```topic```/
# * /sherlock/objects/
# * /sherlock/position/
#
#
# ### Python (3 only) requirements - pip install
# lasair

# %%
# !pip install lasair
# Out:
# DEPRECATION: Loading egg at /Users/roywilliams/Library/Python/3.11/lib/python/site-packages/pyglet-2.0.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: lasair in /usr/local/lib/python3.11/site-packages (0.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from lasair) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->lasair) (2022.12.7)

# %% [markdown]
# ### Grab my Lasair API token
# Get your Lasair token before you start. You can log into [Lasair](https://lasair.lsst.ac.uk) and click "My Profile"
# at top right. Or use the command-line below.
# ```bash
# curl --data "username=myusername&password=***********" https://lasair-ztf.lsst.ac.uk/api/auth-token/
# ```
# Make a file called settings.py with a line like: `API_TOKEN = '0123456789abcdefxxxxxxxxxxxxxxxxxxxxxxxx'`

# %%
import settings
from lasair import LasairError, lasair_client as lasair
import json

# %% [markdown]
# ### Here are some objects

# %%
objs = {
'ZTF23aboahkf':{'ra':	171.41988, 'dec':	 4.335347},
'ZTF23ablcrxf':{'ra':	135.85068, 'dec':	 2.445977},
'ZTF23ablcnik':{'ra':	139.62140, 'dec':	 3.454749},
'ZTF23abiuptv':{'ra':	163.70436, 'dec':	22.694256},
'ZTF23abiuafq':{'ra':	154.91008, 'dec':	26.308471},
'ZTF23abgolun':{'ra':	256.72185, 'dec':	 9.427679},
}

# %% [markdown]
# Start the Lasair API client

# %%
L = lasair(settings.API_TOKEN, endpoint = "https://lasair-ztf.lsst.ac.uk/api")

# %% [markdown]
# ### Get Sherlock info by objectId

# %%
result = L.sherlock_objects(objs.keys(), lite = True)

for k, v in result['classifications'].items():
    print(k, json.dumps(v, indent=2))

for row in result['crossmatches']:
    print(json.dumps(row, indent=2))

print(len(result['crossmatches']))
# Out:
# ZTF23abgolun [
#   "SN",
#   "The transient is possibly associated with <em>119312567216573824</em>; an r=20.66 mag galaxy found in the PS1 catalogue. It's located 0.53\" S, 0.54\" E from the galaxy centre."
# ]
# ZTF23abiuafq [
#   "NT",
#   "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=SDSSJ101938.41%2B261830.6&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">SDSSJ101938.41%2B261830.6</a></em>; an r=17.45 mag galaxy found in the NED/SDSS catalogues. It's located 0.2\" (0.5 Kpc) from the galaxy core. A host z=0.175 implies a <em>m - M =</em> 39.63."
# ]
# ZTF23abiuptv [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237667536939188371\">SDSS J105449.04+224139.3</a></em>; a V=16.68 mag galaxy found in the SDSS/GSC catalogues. It's located 0.0\" (0.0 Kpc) from the galaxy core. A host z=0.078 implies a <em>m - M =</em> 37.76."
# ]
# ZTF23ablcnik [
#   "NT",
#   "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=SDSSJ091829.11%2B032717.1&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">SDSSJ091829.11%2B032717.1</a></em>; an r=17.29 mag galaxy found in the NED/SDSS catalogues. It's located 0.4\" (0.6 Kpc) from the galaxy core. A host z=0.086 implies a <em>m - M =</em> 37.98."
# ]
# ZTF23ablcrxf [
#   "NT",
#   "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=2MASXJ09032416%2B0226451&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">2MASXJ09032416%2B0226451</a></em>; an r=17.41 mag galaxy found in the NED/SDSS catalogues. It's located 0.4\" (1.3 Kpc) from the galaxy core. A host z=0.188 implies a <em>m - M =</em> 39.81."
# ]
# ZTF23aboahkf [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237654604793839677\">SDSS J112540.80+042007.6</a></em>; an r=16.41 mag galaxy found in the SDSS catalogue. It's located 0.7\" (1.3 Kpc) from the galaxy core. A host z=0.098 implies a <em>m - M =</em> 38.27."
# ]
# {
#   "transient_object_id": "ZTF23abgolun",
#   "association_type": "SN",
#   "catalogue_table_name": "PS1",
#   "catalogue_object_id": "119312567216573824",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 256.721695208,
#   "decDeg": 9.42782506,
#   "separationArcsec": 0.76,
#   "northSeparationArcsec": "0.52726",
#   "eastSeparationArcsec": "-0.54440",
#   "physical_separation_kpc": null,
#   "direct_distance": null,
#   "distance": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "Mag": 20.66,
#   "MagFilter": "r",
#   "MagErr": 0.0,
#   "classificationReliability": 2,
#   "major_axis_arcsec": 5.21
# }
# {
#   "transient_object_id": "ZTF23abiuafq",
#   "association_type": "NT",
#   "catalogue_table_name": "NED/SDSS",
#   "catalogue_object_id": "SDSSJ101938.41+261830.6",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 154.91008110849373,
#   "decDeg": 26.308520420379406,
#   "separationArcsec": 0.18,
#   "northSeparationArcsec": "0.214",
#   "eastSeparationArcsec": "0.016",
#   "physical_separation_kpc": 0.53,
#   "direct_distance": null,
#   "distance": 843.76,
#   "z": 0.17,
#   "photoZ": null,
#   "photoZErr": 0.0,
#   "Mag": 17.45,
#   "MagFilter": "r",
#   "MagErr": 0.01,
#   "classificationReliability": 1,
#   "major_axis_arcsec": 9.6
# }
# {
#   "transient_object_id": "ZTF23abiuptv",
#   "association_type": "NT",
#   "catalogue_table_name": "SDSS/GSC",
#   "catalogue_object_id": "1237667536939188371",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 163.70435984853833,
#   "decDeg": 22.694257325998745,
#   "separationArcsec": 0.01,
#   "northSeparationArcsec": "0.2053",
#   "eastSeparationArcsec": "0.1374",
#   "physical_separation_kpc": 0.01,
#   "direct_distance": null,
#   "distance": 355.99,
#   "z": 0.08,
#   "photoZ": null,
#   "photoZErr": null,
#   "Mag": 16.72,
#   "MagFilter": "r",
#   "MagErr": 0.0,
#   "classificationReliability": 1,
#   "major_axis_arcsec": null
# }
# {
#   "transient_object_id": "ZTF23ablcnik",
#   "association_type": "NT",
#   "catalogue_table_name": "NED/SDSS",
#   "catalogue_object_id": "SDSSJ091829.11+032717.1",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 139.62129324086183,
#   "decDeg": 3.4547507021812986,
#   "separationArcsec": 0.37,
#   "northSeparationArcsec": "0.0",
#   "eastSeparationArcsec": "-0.4",
#   "physical_separation_kpc": 0.59,
#   "direct_distance": null,
#   "distance": 393.62,
#   "z": 0.09,
#   "photoZ": null,
#   "photoZErr": 0.0,
#   "Mag": 17.29,
#   "MagFilter": "r",
#   "MagErr": 0.01,
#   "classificationReliability": 1,
#   "major_axis_arcsec": 10.2
# }
# {
#   "transient_object_id": "ZTF23ablcrxf",
#   "association_type": "NT",
#   "catalogue_table_name": "NED/SDSS",
#   "catalogue_object_id": "2MASXJ09032416+0226451",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 135.850791667,
#   "decDeg": 2.44594444444,
#   "separationArcsec": 0.43,
#   "northSeparationArcsec": "-0.1179",
#   "eastSeparationArcsec": "0.4124",
#   "physical_separation_kpc": 1.35,
#   "direct_distance": null,
#   "distance": 914.88,
#   "z": 0.19,
#   "photoZ": null,
#   "photoZErr": 0.0,
#   "Mag": 17.41,
#   "MagFilter": "r",
#   "MagErr": 0.01,
#   "classificationReliability": 1,
#   "major_axis_arcsec": 10.2
# }
# {
#   "transient_object_id": "ZTF23aboahkf",
#   "association_type": "NT",
#   "catalogue_table_name": "SDSS",
#   "catalogue_object_id": "1237654604793839677",
#   "catalogue_object_type": "galaxy",
#   "raDeg": 171.42004074730409,
#   "decDeg": 4.3354624221364,
#   "separationArcsec": 0.71,
#   "northSeparationArcsec": "0.4165996910",
#   "eastSeparationArcsec": "0.5738037080",
#   "physical_separation_kpc": 1.29,
#   "direct_distance": null,
#   "distance": 450.89,
#   "z": 0.1,
#   "photoZ": null,
#   "photoZErr": null,
#   "Mag": 16.41,
#   "MagFilter": "r",
#   "MagErr": 0.02,
#   "classificationReliability": 1,
#   "major_axis_arcsec": null
# }
# 6

# %% [markdown]
# ### Get Sherlock by Position

# %%
for objectId, position in objs.items():
    result = L.sherlock_position(position['ra'], position['dec'], lite = True)
    print(json.dumps(result, indent=2))
# Out:
# {
#   "classifications": {
#     "transient_00000": [
#       "NT",
#       "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237654604793839677\">SDSS J112540.80+042007.6</a></em>; an r=16.41 mag galaxy found in the SDSS catalogue. It's located 0.7\" (1.3 Kpc) from the galaxy core. A host z=0.098 implies a <em>m - M =</em> 38.27."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "NT",
#       "catalogue_table_name": "SDSS",
#       "catalogue_object_id": "1237654604793839677",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 171.42004074730409,
#       "decDeg": 4.3354624221364,
#       "separationArcsec": 0.71,
#       "northSeparationArcsec": "0.416",
#       "eastSeparationArcsec": "0.577",
#       "physical_separation_kpc": 1.29,
#       "direct_distance": null,
#       "distance": 450.89,
#       "z": 0.1,
#       "photoZ": null,
#       "photoZErr": null,
#       "Mag": 16.41,
#       "MagFilter": "r",
#       "MagErr": 0.02,
#       "classificationReliability": 1,
#       "major_axis_arcsec": null
#     }
#   ]
# }
# {
#   "classifications": {
#     "transient_00000": [
#       "NT",
#       "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=2MASXJ09032416%2B0226451&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">2MASXJ09032416%2B0226451</a></em>; an r=17.41 mag galaxy found in the NED/SDSS catalogues. It's located 0.4\" (1.3 Kpc) from the galaxy core. A host z=0.188 implies a <em>m - M =</em> 39.81."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "NT",
#       "catalogue_table_name": "NED/SDSS",
#       "catalogue_object_id": "2MASXJ09032416+0226451",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 135.850791667,
#       "decDeg": 2.44594444444,
#       "separationArcsec": 0.42,
#       "northSeparationArcsec": "-0.1172",
#       "eastSeparationArcsec": "0.4016",
#       "physical_separation_kpc": 1.31,
#       "direct_distance": null,
#       "distance": 914.88,
#       "z": 0.19,
#       "photoZ": null,
#       "photoZErr": 0.0,
#       "Mag": 17.41,
#       "MagFilter": "r",
#       "MagErr": 0.01,
#       "classificationReliability": 1,
#       "major_axis_arcsec": 10.2
#     }
#   ]
# }
# {
#   "classifications": {
#     "transient_00000": [
#       "NT",
#       "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=SDSSJ091829.11%2B032717.1&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">SDSSJ091829.11%2B032717.1</a></em>; an r=17.29 mag galaxy found in the NED/SDSS catalogues. It's located 0.4\" (0.6 Kpc) from the galaxy core. A host z=0.086 implies a <em>m - M =</em> 37.98."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "NT",
#       "catalogue_table_name": "NED/SDSS",
#       "catalogue_object_id": "SDSSJ091829.11+032717.1",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 139.62129324086183,
#       "decDeg": 3.4547507021812986,
#       "separationArcsec": 0.38,
#       "northSeparationArcsec": "0.0",
#       "eastSeparationArcsec": "-0.4",
#       "physical_separation_kpc": 0.62,
#       "direct_distance": null,
#       "distance": 393.62,
#       "z": 0.09,
#       "photoZ": null,
#       "photoZErr": 0.0,
#       "Mag": 17.29,
#       "MagFilter": "r",
#       "MagErr": 0.01,
#       "classificationReliability": 1,
#       "major_axis_arcsec": 10.2
#     }
#   ]
# }
# {
#   "classifications": {
#     "transient_00000": [
#       "NT",
#       "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237667536939188371\">SDSS J105449.04+224139.3</a></em>; a V=16.68 mag galaxy found in the SDSS/GSC catalogues. It's located 0.0\" (0.0 Kpc) from the galaxy core. A host z=0.078 implies a <em>m - M =</em> 37.76."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "NT",
#       "catalogue_table_name": "SDSS/GSC",
#       "catalogue_object_id": "1237667536939188371",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 163.70435984853833,
#       "decDeg": 22.694257325998745,
#       "separationArcsec": 0.01,
#       "northSeparationArcsec": "0.204",
#       "eastSeparationArcsec": "0.142",
#       "physical_separation_kpc": 0.01,
#       "direct_distance": null,
#       "distance": 355.99,
#       "z": 0.08,
#       "photoZ": null,
#       "photoZErr": null,
#       "Mag": 16.72,
#       "MagFilter": "r",
#       "MagErr": 0.0,
#       "classificationReliability": 1,
#       "major_axis_arcsec": null
#     }
#   ]
# }
# {
#   "classifications": {
#     "transient_00000": [
#       "NT",
#       "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=SDSSJ101938.41%2B261830.6&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">SDSSJ101938.41%2B261830.6</a></em>; an r=17.45 mag galaxy found in the NED/SDSS catalogues. It's located 0.2\" (0.5 Kpc) from the galaxy core. A host z=0.175 implies a <em>m - M =</em> 39.63."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "NT",
#       "catalogue_table_name": "NED/SDSS",
#       "catalogue_object_id": "SDSSJ101938.41+261830.6",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 154.91008110849373,
#       "decDeg": 26.308520420379406,
#       "separationArcsec": 0.18,
#       "northSeparationArcsec": "0.212",
#       "eastSeparationArcsec": "0.011",
#       "physical_separation_kpc": 0.53,
#       "direct_distance": null,
#       "distance": 843.76,
#       "z": 0.17,
#       "photoZ": null,
#       "photoZErr": 0.0,
#       "Mag": 17.45,
#       "MagFilter": "r",
#       "MagErr": 0.01,
#       "classificationReliability": 1,
#       "major_axis_arcsec": 9.6
#     }
#   ]
# }
# {
#   "classifications": {
#     "transient_00000": [
#       "SN",
#       "The transient is possibly associated with <em>119312567216573824</em>; an r=20.66 mag galaxy found in the PS1 catalogue. It's located 0.53\" S, 0.55\" E from the galaxy centre."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "SN",
#       "catalogue_table_name": "PS1",
#       "catalogue_object_id": "119312567216573824",
#       "catalogue_object_type": "galaxy",
#       "raDeg": 256.721695208,
#       "decDeg": 9.42782506,
#       "separationArcsec": 0.76,
#       "northSeparationArcsec": "0.53",
#       "eastSeparationArcsec": "-0.55",
#       "physical_separation_kpc": null,
#       "direct_distance": null,
#       "distance": null,
#       "z": null,
#       "photoZ": null,
#       "photoZErr": null,
#       "Mag": 20.66,
#       "MagFilter": "r",
#       "MagErr": 0.0,
#       "classificationReliability": 2,
#       "major_axis_arcsec": 5.21
#     }
#   ]
# }
