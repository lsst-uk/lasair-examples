# %% [markdown]
# # Sherlock (Context Classification)
# ### Ken Smith
# The Sherlock service gives the context of a list of objects in the sky based on numerous large catalogues (e.g. Pan-STARRS1, Gaia DR2, etc.).  The service can also accept an arbitrary position in the sky.
#
# Demonstrates usage of:
# * /streams/```topic```/
# * /sherlock/objects/
# * /sherlock/position/
#
#
# ### Python (3 only) requirements - pip install
# lasair

# %%
# !pip install lasair
# Out:
# Collecting lasair
#   Downloading https://files.pythonhosted.org/packages/80/42/f4f51627819faec499c87420dba07ca759a150c3c0e09148796bc6568950/lasair-0.0.1.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from lasair) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->lasair) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->lasair) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->lasair) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->lasair) (2020.12.5)
# Building wheels for collected packages: lasair
#   Building wheel for lasair (setup.py) ... done
#   Created wheel for lasair: filename=lasair-0.0.1-cp37-none-any.whl size=5400 sha256=8400a2da515296904e540d3a36a5ca4e3d34deb29058262dba503860b8c48b22
#   Stored in directory: /root/.cache/pip/wheels/90/14/ca/ebc366bda99df15e2f2a285ad518e6f54e586f9e493a761c8a
# Successfully built lasair
# Installing collected packages: lasair
# Successfully installed lasair-0.0.1

# %% [markdown]
# ### Grab my Lasair API token
# Get your token before you start.  If you haven't got a Lasair account you can register here: https://lasair-ztf.lsst.ac.uk/signup.  Use the curl command below to get your token & set the last line of the next cell to be your token ID.
#
# ```bash
# curl --data "username=myusername&password=***********" https://lasair-ztf.lsst.ac.uk/api/auth-token/
# ```
# You should get the following response:
# ```json
# {"token":"4b762569bb349bd8d60f1bc7da3f39dbfaefff9a"}
# ```
# We can use this token temporarily, but note that this test token will only allow a very small number of requests per hour!  Hence it may be disabled when you come to test this code.

# %%
from lasair import LasairError, lasair_client as lasair
import json

token = "4b762569bb349bd8d60f1bc7da3f39dbfaefff9a"

# %% [markdown]
# ### Get a bunch of objects
# Why not just grab a few objects from one of the topics (e.g. the 2SN-likecandidates topic)

# %%
topic = "lasair_2SN-likecandidates"

L = lasair(token, endpoint = "https://lasair-ztf.lsst.ac.uk/api")

try:
    result = L.streams(topic, limit=10)
except LasairError as e:
    print(e)

objectIds = [row['objectId'] for row in result]

# %% [markdown]
# ### Now get Sherlock info for these objects

# %%
try:
    result = L.sherlock_objects(objectIds, lite = True)
except LasairError as e:
    print(e)

for k, v in result['classifications'].items():
    print(k, json.dumps(v, indent=2))

for row in result['crossmatches']:
    print(json.dumps(row, indent=2))

print(len(result['crossmatches']))
# Out:
# ZTF18aaporis [
#   "SN",
#   "The transient is possibly associated with <em>164882816819775546</em>; an r=23.69 mag galaxy found in the PS1 catalogue. It's located 0.10\" S, 0.05\" W from the galaxy centre."
# ]
# ZTF18aaymybb [
#   "NT",
#   "The transient is synonymous with <em>19143756+5028546</em>; a J=15.99 mag stellar source found in the 2MASS/GAIA/GLADE catalogues. It's located 0.1\" from the stellar source core."
# ]
# ZTF18abccnyj [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237674894739898535\">SDSS J210625.32+221941.5</a></em>; a J=15.25 mag galaxy found in the SDSS/2MASS/GAIA catalogues. It's located 0.1\" from the galaxy core."
# ]
# ZTF18abjgzxw [
#   "NT",
#   "The transient is synonymous with <em>21144752+2514148</em>; a B=17.37 mag stellar source found in the 2MASS/GAIA/GLADE catalogues. It's located 0.1\" from the stellar source core."
# ]
# ZTF18abtimkh [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237668709456741129\">SDSS J195310.0-101746.7</a></em>; a J=15.20 mag galaxy found in the SDSS/2MASS/GAIA catalogues. It's located 0.4\" from the galaxy core."
# ]
# ZTF19aarybds [
#   "SN",
#   "The transient is possibly associated with <em>107782901601745649</em>; an r=20.61 mag galaxy found in the PS1 catalogue. It's located 4.85\" N, 0.90\" W from the galaxy centre."
# ]
# ZTF19aasrgim [
#   "SN",
#   "The transient is possibly associated with <em>19424504+5138372</em>; a B=17.16 mag galaxy found in the 2MASS/GLADE/PS1 catalogues. It's located 23.91\" S, 15.01\" E from the galaxy centre."
# ]
# ZTF21aakjbdm [
#   "SN",
#   "The transient is possibly associated with <em>19350734+4953102</em>; a B=15.97 mag galaxy found in the 2MASS/GLADE/PS1 catalogues. It's located 6.14\" S, 2.17\" W from the galaxy centre."
# ]
# ZTF21aaquxot [
#   "SN",
#   "The transient is possibly associated with <em>92512912838754874</em>; an r=23.09 mag galaxy found in the PS1 catalogue. It's located 0.82\" N, 1.75\" W from the galaxy centre."
# ]
# ZTF21aarjjsb [
#   "UNCLEAR",
#   "The transient is possibly associated with <em>97432953441523114</em>; an r=22.32 mag uncertain found in the PS1 catalogue. It's located 0.13\" S, 0.03\" E from the uncertain centre."
# ]
# {
#   "catalogue_object_id": "164882816819775546",
#   "_g": 23.762300491333008,
#   "_gErr": 0.01696299947798252,
#   "_r": 23.691299438476562,
#   "_rErr": 0.016224000602960587,
#   "_i": 23.224899291992188,
#   "_iErr": 0.009313000366091728,
#   "_z": 22.270599365234375,
#   "_zErr": 0.00930199958384037,
#   "_y": 23.34079933166504,
#   "_yErr": 0.014630000106990337,
#   "separationArcsec": 0.11013560904794928,
#   "northSeparationArcsec": "0.09793",
#   "eastSeparationArcsec": "0.05036",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF18aaporis",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 281.68202689,
#   "decDeg": 47.403995124,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 164882816819775546,
#   "_g": 23.762300491333008,
#   "_gErr": 0.01696299947798252,
#   "_r": 23.691299438476562,
#   "_rErr": 0.016224000602960587,
#   "_i": 23.224899291992188,
#   "_iErr": 0.009313000366091728,
#   "_z": 22.270599365234375,
#   "_zErr": 0.00930199958384037,
#   "_y": 23.34079933166504,
#   "_yErr": 0.014630000106990337,
#   "separationArcsec": 0.11013560904794928,
#   "northSeparationArcsec": "0.09793",
#   "eastSeparationArcsec": "0.05036",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF18aaporis",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 281.68202689,
#   "decDeg": 47.403995124,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "19143756+5028546",
#   "J": 15.994,
#   "JErr": 0.091,
#   "H": 15.298,
#   "HErr": 0.099,
#   "K": 14.509,
#   "KErr": 0.084,
#   "separationArcsec": 0.05799228818245006,
#   "northSeparationArcsec": "0.0913452632",
#   "eastSeparationArcsec": "-0.0692292244",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF18aaymybb",
#   "catalogue_table_name": "2MASS/GAIA/GLADE",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "multiple",
#   "raDeg": 288.6565166603808,
#   "decDeg": 50.48184721026213,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "G": 18.3955,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 1010.0579922881825,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "19143756+5028546 ",
#   "J": 15.994,
#   "JErr": 0.091,
#   "H": 15.298,
#   "HErr": 0.099,
#   "K": 14.509,
#   "KErr": 0.084,
#   "separationArcsec": 0.1146327763428054,
#   "northSeparationArcsec": "0.0913452632",
#   "eastSeparationArcsec": "-0.0692292244",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF18aaymybb",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 288.656504,
#   "decDeg": 50.481861,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0579922881825,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 2132923537067872384,
#   "G": 18.3955,
#   "separationArcsec": 0.05799228818245006,
#   "northSeparationArcsec": "0.0417022068",
#   "eastSeparationArcsec": "-0.0402273170",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF18aaymybb",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 288.6565166603808,
#   "decDeg": 50.48184721026213,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0579922881825,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "19143758+5028547",
#   "J": 15.227,
#   "JErr": 0.174,
#   "H": 14.881,
#   "HErr": 0.0,
#   "K": 13.902,
#   "KErr": 0.216,
#   "separationArcsec": 0.24619397677380306,
#   "northSeparationArcsec": "0.1597",
#   "eastSeparationArcsec": "0.1873",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF18aaymybb",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 288.656616,
#   "decDeg": 50.48188,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0579922881825,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "19143758+5028547",
#   "z": null,
#   "distance": null,
#   "B": null,
#   "BErr": null,
#   "J": 15.554,
#   "JErr": 0.128,
#   "H": null,
#   "HErr": null,
#   "K": 14.109,
#   "KErr": 0.141,
#   "separationArcsec": 0.24619397677380306,
#   "northSeparationArcsec": "0.1597",
#   "eastSeparationArcsec": "0.1873",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF18aaymybb",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy 2 angular",
#   "raDeg": 288.656616,
#   "decDeg": 50.48188,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0579922881825
# }
# {
#   "catalogue_object_id": "1237674894739898535",
#   "J": 15.25,
#   "JErr": 0.056,
#   "H": 14.693,
#   "HErr": 0.064,
#   "K": 14.492,
#   "KErr": 0.076,
#   "separationArcsec": 0.10589381759085177,
#   "northSeparationArcsec": "0.1601",
#   "eastSeparationArcsec": "0.2321",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF18abccnyj",
#   "catalogue_table_name": "SDSS/2MASS/GAIA",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 316.60551008604403,
#   "decDeg": 22.328219007216845,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.130274,
#   "photoZErr": 0.026779,
#   "_r": 17.0363,
#   "_rErr": 0.00443459,
#   "_g": 18.2367,
#   "_gErr": 0.0076935,
#   "_i": 16.5358,
#   "_iErr": 0.00417871,
#   "_z": 16.201,
#   "_zErr": 0.0106494,
#   "_u": 20.5609,
#   "_uErr": 0.129919,
#   "catalogue_object_subtype": "multiple",
#   "G": 17.5075,
#   "rankScore": 1010.1058938175909,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "21062533+2219417 ",
#   "J": 15.25,
#   "JErr": 0.056,
#   "H": 14.693,
#   "HErr": 0.064,
#   "K": 14.492,
#   "KErr": 0.076,
#   "separationArcsec": 0.2820003884935611,
#   "northSeparationArcsec": "0.1601",
#   "eastSeparationArcsec": "0.2321",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF18abccnyj",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 316.605551,
#   "decDeg": 22.328251,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1058938175909,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237674894739898535,
#   "photoZ": 0.130274,
#   "photoZErr": 0.026779,
#   "_u": 20.5609,
#   "_uErr": 0.129919,
#   "_g": 18.2367,
#   "_gErr": 0.0076935,
#   "_r": 17.0363,
#   "_rErr": 0.00443459,
#   "_i": 16.5358,
#   "_iErr": 0.00417871,
#   "_z": 16.201,
#   "_zErr": 0.0106494,
#   "separationArcsec": 0.1552388708626744,
#   "northSeparationArcsec": "0.06243",
#   "eastSeparationArcsec": "0.14215",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF18abccnyj",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 316.6055239871955,
#   "decDeg": 22.328223861140284,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1058938175909
# }
# {
#   "catalogue_object_id": 1838466179892573440,
#   "G": 17.5075,
#   "separationArcsec": 0.10589381759085177,
#   "northSeparationArcsec": "0.04495",
#   "eastSeparationArcsec": "0.09586",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF18abccnyj",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 316.60551008604403,
#   "decDeg": 22.328219007216845,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1058938175909,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "21144752+2514148",
#   "J": 15.068,
#   "JErr": 0.058,
#   "H": 14.094,
#   "HErr": 0.06,
#   "K": 13.032,
#   "KErr": 0.044,
#   "separationArcsec": 0.07082596597551558,
#   "northSeparationArcsec": "0.200288571",
#   "eastSeparationArcsec": "0.030191249",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF18abjgzxw",
#   "catalogue_table_name": "2MASS/GAIA/GLADE",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "multiple",
#   "raDeg": 318.6979974967665,
#   "decDeg": 25.23742818671626,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "G": 16.885,
#   "catalogue_object_subtype": "multiple",
#   "B": 17.37,
#   "BErr": null,
#   "rankScore": 1010.0708259659755,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "21144752+2514148 ",
#   "J": 15.068,
#   "JErr": 0.058,
#   "H": 14.094,
#   "HErr": 0.06,
#   "K": 13.032,
#   "KErr": 0.044,
#   "separationArcsec": 0.20257700881835095,
#   "northSeparationArcsec": "0.200288571",
#   "eastSeparationArcsec": "0.030191249",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF18abjgzxw",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 318.698018,
#   "decDeg": 25.237467,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0708259659755,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 1840795430852928128,
#   "G": 16.885,
#   "separationArcsec": 0.07082596597551558,
#   "northSeparationArcsec": "0.060560750",
#   "eastSeparationArcsec": "-0.036574976",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF18abjgzxw",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 318.6979974967665,
#   "decDeg": 25.23742818671626,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0708259659755,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "21144749+2514144",
#   "J": 14.607,
#   "JErr": 0.132,
#   "H": 13.849,
#   "HErr": 0.152,
#   "K": 12.81,
#   "KErr": 0.105,
#   "separationArcsec": 0.48704445388006307,
#   "northSeparationArcsec": "-0.2245",
#   "eastSeparationArcsec": "-0.4322",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF18abjgzxw",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 318.697876,
#   "decDeg": 25.237349,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0708259659755,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "21144749+2514144",
#   "z": null,
#   "distance": null,
#   "B": 17.37,
#   "BErr": null,
#   "J": 14.816,
#   "JErr": 0.091,
#   "H": 13.906,
#   "HErr": 0.087,
#   "K": 12.886,
#   "KErr": 0.076,
#   "separationArcsec": 0.48704445388006307,
#   "northSeparationArcsec": "-0.2245",
#   "eastSeparationArcsec": "-0.4322",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF18abjgzxw",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 318.697876,
#   "decDeg": 25.237349,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.0708259659755
# }
# {
#   "catalogue_object_id": "1237668709456741129",
#   "J": 15.195,
#   "JErr": 0.086,
#   "H": 14.299,
#   "HErr": 0.081,
#   "K": 13.445,
#   "KErr": 0.059,
#   "separationArcsec": 0.428244282287077,
#   "northSeparationArcsec": "0.1876",
#   "eastSeparationArcsec": "0.3850",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF18abtimkh",
#   "catalogue_table_name": "SDSS/2MASS/GAIA",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 298.291848,
#   "decDeg": -10.296314,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.14983,
#   "photoZErr": 0.016965,
#   "G": 17.2743,
#   "catalogue_object_subtype": "multiple",
#   "_r": 16.9832,
#   "_rErr": 0.0196495,
#   "_g": 17.4855,
#   "_gErr": 0.0125568,
#   "_i": 16.3248,
#   "_iErr": 0.010706,
#   "_z": 16.3196,
#   "_zErr": 0.019317,
#   "_u": 17.882,
#   "_uErr": 0.0174792,
#   "rankScore": 1010.4282442822871,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "19531004-1017467 ",
#   "J": 15.195,
#   "JErr": 0.086,
#   "H": 14.299,
#   "HErr": 0.081,
#   "K": 13.445,
#   "KErr": 0.059,
#   "separationArcsec": 0.428244282287077,
#   "northSeparationArcsec": "0.1876",
#   "eastSeparationArcsec": "0.3850",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF18abtimkh",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 298.291848,
#   "decDeg": -10.296314,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.4282442822871,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 4190511977674345984,
#   "G": 17.2743,
#   "separationArcsec": 0.43994159868805227,
#   "northSeparationArcsec": "0.20257",
#   "eastSeparationArcsec": "0.39052",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF18abtimkh",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 298.29184956974234,
#   "decDeg": -10.296309845913042,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.4282442822871,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237668709456741129,
#   "photoZ": 0.14983,
#   "photoZErr": 0.016965,
#   "_u": 17.882,
#   "_uErr": 0.0174792,
#   "_g": 17.4855,
#   "_gErr": 0.0125568,
#   "_r": 16.9832,
#   "_rErr": 0.0196495,
#   "_i": 16.3248,
#   "_iErr": 0.010706,
#   "_z": 16.3196,
#   "_zErr": 0.019317,
#   "separationArcsec": 0.4524855986759276,
#   "northSeparationArcsec": "0.19387",
#   "eastSeparationArcsec": "0.40885",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF18abtimkh",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 298.2918547450388,
#   "decDeg": -10.296312263259313,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.4282442822871
# }
# {
#   "catalogue_object_id": "107782901601745649",
#   "_g": 21.61520004272461,
#   "_gErr": 0.007519999984651804,
#   "_r": 20.61479949951172,
#   "_rErr": 0.0043680001981556416,
#   "_i": 20.91860008239746,
#   "_iErr": 0.0047889999113976955,
#   "_z": null,
#   "_zErr": 0.007985999807715416,
#   "_y": null,
#   "_yErr": 0.0048340000212192535,
#   "separationArcsec": 4.934618665657136,
#   "northSeparationArcsec": "-4.8511625",
#   "eastSeparationArcsec": "0.9037067",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 290.160132988,
#   "decDeg": -0.178974288,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 107782901601745649,
#   "_g": 21.61520004272461,
#   "_gErr": 0.007519999984651804,
#   "_r": 20.61479949951172,
#   "_rErr": 0.0043680001981556416,
#   "_i": 20.91860008239746,
#   "_iErr": 0.0047889999113976955,
#   "_z": null,
#   "_zErr": 0.007985999807715416,
#   "_y": null,
#   "_yErr": 0.0048340000212192535,
#   "separationArcsec": 4.934618665657136,
#   "northSeparationArcsec": "-4.8511625",
#   "eastSeparationArcsec": "0.9037067",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 290.160132988,
#   "decDeg": -0.178974288,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "107772901736704264",
#   "_g": 17.52519989013672,
#   "_gErr": 0.001142999972216785,
#   "_r": 16.688899993896484,
#   "_rErr": 0.0007159999804571271,
#   "_i": 15.958999633789062,
#   "_iErr": 0.0004879999905824661,
#   "_z": 15.789899826049805,
#   "_zErr": 0.000539999979082495,
#   "_y": 16.286800384521484,
#   "_yErr": 0.0006689999718219042,
#   "separationArcsec": 63.14803526995895,
#   "northSeparationArcsec": "-39.045777",
#   "eastSeparationArcsec": "49.629645",
#   "association_type": "BS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 290.17366804,
#   "decDeg": -0.188472792,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "rankScore": 2063.148035269959,
#   "rank": 2,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "107772901726962740",
#   "_g": null,
#   "_gErr": 0.009138000197708607,
#   "_r": null,
#   "_rErr": 0.0006300000241026282,
#   "_i": 15.211899757385254,
#   "_iErr": 0.0003459999861661345,
#   "_z": 15.205400466918945,
#   "_zErr": 0.00041199999395757914,
#   "_y": 14.454899787902832,
#   "_yErr": 0.0002880000101868063,
#   "separationArcsec": 63.28597192844073,
#   "northSeparationArcsec": "-43.179002",
#   "eastSeparationArcsec": "46.267570",
#   "association_type": "BS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 290.172734126,
#   "decDeg": -0.18962091,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "rankScore": 2063.2859719284406,
#   "rank": 3,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "107772901432611714",
#   "_g": 12.367799758911133,
#   "_gErr": 0.00010599999950500205,
#   "_r": 15.150199890136719,
#   "_rErr": 0.0003530000103637576,
#   "_i": 20.004199981689453,
#   "_iErr": 0.0031429999507963657,
#   "_z": 13.349300384521484,
#   "_zErr": 0.00017499999376013875,
#   "_y": 13.32229995727539,
#   "_yErr": 0.00017100000695791095,
#   "separationArcsec": 75.85374474131754,
#   "northSeparationArcsec": "-46.4309537",
#   "eastSeparationArcsec": "-59.9829738",
#   "association_type": "BS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 290.143219934,
#   "decDeg": -0.19052423,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "rankScore": 2075.8537447413173,
#   "rank": 4,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "107772901429270176",
#   "_g": 18.012800216674805,
#   "_gErr": 0.0014309999532997608,
#   "_r": 15.94379997253418,
#   "_rErr": 0.0005080000264570117,
#   "_i": 15.669300079345703,
#   "_iErr": 0.00042699999175965786,
#   "_z": null,
#   "_zErr": 0.0050940001383423805,
#   "_y": 16.999799728393555,
#   "_yErr": 0.0009289999725297093,
#   "separationArcsec": 79.59404992935552,
#   "northSeparationArcsec": "-51.0914993",
#   "eastSeparationArcsec": "-61.0317253",
#   "association_type": "BS",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 290.142928612,
#   "decDeg": -0.191818826,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2079.5940499293556,
#   "rank": 5
# }
# {
#   "catalogue_object_id": 107772901429270176,
#   "_g": 18.012800216674805,
#   "_gErr": 0.0014309999532997608,
#   "_r": 15.94379997253418,
#   "_rErr": 0.0005080000264570117,
#   "_i": 15.669300079345703,
#   "_iErr": 0.00042699999175965786,
#   "_z": null,
#   "_zErr": 0.0050940001383423805,
#   "_y": 16.999799728393555,
#   "_yErr": 0.0009289999725297093,
#   "separationArcsec": 79.59404992935552,
#   "northSeparationArcsec": "-51.0914993",
#   "eastSeparationArcsec": "-61.0317253",
#   "association_type": "BS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aarybds",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 290.142928612,
#   "decDeg": -0.191818826,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 5,
#   "rankScore": 2079.5940499293556,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "19424504+5138372",
#   "J": 14.102,
#   "JErr": 0.045,
#   "H": 13.41,
#   "HErr": 0.044,
#   "K": 13.059,
#   "KErr": 0.081,
#   "separationArcsec": 27.928291734205015,
#   "northSeparationArcsec": "23.908",
#   "eastSeparationArcsec": "-15.009",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "2MASS/GLADE/PS1",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 295.68791688,
#   "decDeg": 51.64367264,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "B": 17.165,
#   "BErr": null,
#   "catalogue_object_subtype": "multiple",
#   "_r": 16.549400329589844,
#   "_rErr": 0.0007040000054985285,
#   "_g": 17.341299057006836,
#   "_gErr": 0.0008789999992586672,
#   "_i": 16.09320068359375,
#   "_iErr": 0.00039000000106170774,
#   "_z": 15.903200149536133,
#   "_zErr": 0.0005719999899156392,
#   "_y": 15.702500343322754,
#   "_yErr": 0.0004970000009052455,
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "19424504+5138372",
#   "J": 13.917,
#   "JErr": 0.059,
#   "H": 13.313,
#   "HErr": 0.067,
#   "K": 12.954,
#   "KErr": 0.118,
#   "separationArcsec": 28.228344967842073,
#   "northSeparationArcsec": "23.908",
#   "eastSeparationArcsec": "-15.009",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 295.687683,
#   "decDeg": 51.643681,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "2397543",
#   "z": null,
#   "distance": null,
#   "B": 17.165,
#   "BErr": null,
#   "J": 14.102,
#   "JErr": 0.045,
#   "H": 13.41,
#   "HErr": 0.044,
#   "K": 13.059,
#   "KErr": 0.081,
#   "separationArcsec": 28.228344967842073,
#   "northSeparationArcsec": "23.908",
#   "eastSeparationArcsec": "-15.009",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy 2 angular",
#   "raDeg": 295.687683,
#   "decDeg": 51.643681,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_id": 169972956879163063,
#   "_g": 17.341299057006836,
#   "_gErr": 0.0008789999992586672,
#   "_r": 16.549400329589844,
#   "_rErr": 0.0007040000054985285,
#   "_i": 16.09320068359375,
#   "_iErr": 0.00039000000106170774,
#   "_z": 15.903200149536133,
#   "_zErr": 0.0005719999899156392,
#   "_y": 15.702500343322754,
#   "_yErr": 0.0004970000009052455,
#   "separationArcsec": 27.928291734205015,
#   "northSeparationArcsec": "23.878",
#   "eastSeparationArcsec": "-14.486",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy i angular",
#   "raDeg": 295.68791688,
#   "decDeg": 51.64367264,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "169962956944065123",
#   "_g": 21.736299514770508,
#   "_gErr": 0.0066559999249875546,
#   "_r": 21.23270034790039,
#   "_rErr": 0.006085999775677919,
#   "_i": 20.47800064086914,
#   "_iErr": 0.0029380000196397305,
#   "_z": 20.632600784301758,
#   "_zErr": 0.005051000043749809,
#   "_y": 20.384899139404297,
#   "_yErr": 0.004298000130802393,
#   "separationArcsec": 0.0657775941539658,
#   "northSeparationArcsec": "0.064",
#   "eastSeparationArcsec": "0.015",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 295.694407484,
#   "decDeg": 51.637057802,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2005.0,
#   "rank": 2
# }
# {
#   "catalogue_object_id": 169962956944065123,
#   "_g": 21.736299514770508,
#   "_gErr": 0.0066559999249875546,
#   "_r": 21.23270034790039,
#   "_rErr": 0.006085999775677919,
#   "_i": 20.47800064086914,
#   "_iErr": 0.0029380000196397305,
#   "_z": 20.632600784301758,
#   "_zErr": 0.005051000043749809,
#   "_y": 20.384899139404297,
#   "_yErr": 0.004298000130802393,
#   "separationArcsec": 0.0657775941539658,
#   "northSeparationArcsec": "0.064",
#   "eastSeparationArcsec": "0.015",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 295.694407484,
#   "decDeg": 51.637057802,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 2,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "169992957009491780",
#   "_g": 15.285599708557129,
#   "_gErr": 0.00034100000630132854,
#   "_r": 14.816300392150879,
#   "_rErr": 0.0003169999981764704,
#   "_i": 14.64739990234375,
#   "_iErr": 0.00019999999494757503,
#   "_z": 14.624199867248535,
#   "_zErr": 0.0003169999981764704,
#   "_y": 14.635700225830078,
#   "_yErr": 0.00030399998649954796,
#   "separationArcsec": 81.2637955746923,
#   "northSeparationArcsec": "79.932",
#   "eastSeparationArcsec": "14.654",
#   "association_type": "BS",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 295.700961322,
#   "decDeg": 51.659243214,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2081.2637955746923,
#   "rank": 3
# }
# {
#   "catalogue_object_id": 169992957009491780,
#   "_g": 15.285599708557129,
#   "_gErr": 0.00034100000630132854,
#   "_r": 14.816300392150879,
#   "_rErr": 0.0003169999981764704,
#   "_i": 14.64739990234375,
#   "_iErr": 0.00019999999494757503,
#   "_z": 14.624199867248535,
#   "_zErr": 0.0003169999981764704,
#   "_y": 14.635700225830078,
#   "_yErr": 0.00030399998649954796,
#   "separationArcsec": 81.2637955746923,
#   "northSeparationArcsec": "79.932",
#   "eastSeparationArcsec": "14.654",
#   "association_type": "BS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aasrgim",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 295.700961322,
#   "decDeg": 51.659243214,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 3,
#   "rankScore": 2081.2637955746923,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "19350734+4953102",
#   "J": 13.516,
#   "JErr": 0.05,
#   "H": 12.881,
#   "HErr": 0.061,
#   "K": 12.518,
#   "KErr": 0.097,
#   "separationArcsec": 6.512299516844948,
#   "northSeparationArcsec": "6.1387",
#   "eastSeparationArcsec": "2.1742",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "2MASS/GLADE/PS1",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 293.780609,
#   "decDeg": 49.886181,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "B": 15.974,
#   "BErr": null,
#   "catalogue_object_subtype": "multiple",
#   "_r": 16.725500106811523,
#   "_rErr": 0.0008019999950192869,
#   "_g": 17.337200164794922,
#   "_gErr": 0.0008490000036545098,
#   "_i": 16.30970001220703,
#   "_iErr": 0.0004299999854993075,
#   "_z": 16.121400833129883,
#   "_zErr": 0.0006639999919570982,
#   "_y": 15.826600074768066,
#   "_yErr": 0.0005280000041238964,
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "19350734+4953102",
#   "J": 13.481,
#   "JErr": 0.069,
#   "H": 12.843,
#   "HErr": 0.085,
#   "K": 12.383,
#   "KErr": 0.115,
#   "separationArcsec": 6.512299516844948,
#   "northSeparationArcsec": "6.1387",
#   "eastSeparationArcsec": "2.1742",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 293.780609,
#   "decDeg": 49.886181,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "2356411",
#   "z": null,
#   "distance": null,
#   "B": 15.974,
#   "BErr": null,
#   "J": 13.516,
#   "JErr": 0.05,
#   "H": 12.881,
#   "HErr": 0.061,
#   "K": 12.518,
#   "KErr": 0.097,
#   "separationArcsec": 6.512299516844948,
#   "northSeparationArcsec": "6.1387",
#   "eastSeparationArcsec": "2.1742",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 293.780609,
#   "decDeg": 49.886181,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_id": 167862937808024016,
#   "_g": 17.337200164794922,
#   "_gErr": 0.0008490000036545098,
#   "_r": 16.725500106811523,
#   "_rErr": 0.0008019999950192869,
#   "_i": 16.30970001220703,
#   "_iErr": 0.0004299999854993075,
#   "_z": 16.121400833129883,
#   "_zErr": 0.0006639999919570982,
#   "_y": 15.826600074768066,
#   "_yErr": 0.0005280000041238964,
#   "separationArcsec": 6.543273652492181,
#   "northSeparationArcsec": "6.0005585",
#   "eastSeparationArcsec": "2.6091613",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 293.780796538,
#   "decDeg": 49.886142639999996,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "167862937783782809",
#   "_g": null,
#   "_gErr": null,
#   "_r": 18.093900680541992,
#   "_rErr": 0.0015059999423101544,
#   "_i": 17.86280059814453,
#   "_iErr": 0.0008800000068731606,
#   "_z": 17.662799835205078,
#   "_zErr": 0.0013510000426322222,
#   "_y": 17.294099807739258,
#   "_yErr": 0.0010379999876022339,
#   "separationArcsec": 4.245702574691001,
#   "northSeparationArcsec": "2.966344",
#   "eastSeparationArcsec": "-3.037564",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 293.778362145,
#   "decDeg": 49.8852998025,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2005.0,
#   "rank": 2
# }
# {
#   "catalogue_object_id": 167862937783782809,
#   "_g": null,
#   "_gErr": null,
#   "_r": 18.093900680541992,
#   "_rErr": 0.0015059999423101544,
#   "_i": 17.86280059814453,
#   "_iErr": 0.0008800000068731606,
#   "_z": 17.662799835205078,
#   "_zErr": 0.0013510000426322222,
#   "_y": 17.294099807739258,
#   "_yErr": 0.0010379999876022339,
#   "separationArcsec": 4.245702574691001,
#   "northSeparationArcsec": "2.966344",
#   "eastSeparationArcsec": "-3.037564",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF21aakjbdm",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 293.778362145,
#   "decDeg": 49.8852998025,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 2,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "92512912838754874",
#   "_g": 23.748199462890625,
#   "_gErr": 0.01777300052344799,
#   "_r": 23.08989906311035,
#   "_rErr": 0.012751000002026558,
#   "_i": 21.903600692749023,
#   "_iErr": 0.007455000188201666,
#   "_z": 20.767499923706055,
#   "_zErr": 0.00507500022649765,
#   "_y": 22.585100173950195,
#   "_yErr": 0.011371999979019165,
#   "separationArcsec": 1.930336258635874,
#   "northSeparationArcsec": "-0.8205275",
#   "eastSeparationArcsec": "1.7472621",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aaquxot",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 291.283865,
#   "decDeg": -12.904574098,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 92512912838754874,
#   "_g": 23.748199462890625,
#   "_gErr": 0.01777300052344799,
#   "_r": 23.08989906311035,
#   "_rErr": 0.012751000002026558,
#   "_i": 21.903600692749023,
#   "_iErr": 0.007455000188201666,
#   "_z": 20.767499923706055,
#   "_zErr": 0.00507500022649765,
#   "_y": 22.585100173950195,
#   "_yErr": 0.011371999979019165,
#   "separationArcsec": 1.930336258635874,
#   "northSeparationArcsec": "-0.8205275",
#   "eastSeparationArcsec": "1.7472621",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF21aaquxot",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 291.283865,
#   "decDeg": -12.904574098,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "97432953441523114",
#   "_g": 25.797199249267578,
#   "_gErr": 0.04768199846148491,
#   "_r": 22.318099975585938,
#   "_rErr": 0.009061000309884548,
#   "_i": 26.5132999420166,
#   "_iErr": 0.06400900334119797,
#   "_z": null,
#   "_zErr": 0.027619000524282455,
#   "_y": 21.975099563598633,
#   "_yErr": 0.00993799977004528,
#   "separationArcsec": 0.13614282166026936,
#   "northSeparationArcsec": "0.13304",
#   "eastSeparationArcsec": "-0.02888",
#   "association_type": "UNCLEAR",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aarjjsb",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 47,
#   "classificationReliability": 3,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "uncertain",
#   "search_name": "PS1",
#   "raDeg": 295.344150282,
#   "decDeg": -8.80607051,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 3010.13614282166,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 97432953441523114,
#   "_g": 25.797199249267578,
#   "_gErr": 0.04768199846148491,
#   "_r": 22.318099975585938,
#   "_rErr": 0.009061000309884548,
#   "_i": 26.5132999420166,
#   "_iErr": 0.06400900334119797,
#   "_z": null,
#   "_zErr": 0.027619000524282455,
#   "_y": 21.975099563598633,
#   "_yErr": 0.00993799977004528,
#   "separationArcsec": 0.13614282166026936,
#   "northSeparationArcsec": "0.13304",
#   "eastSeparationArcsec": "-0.02888",
#   "association_type": "UNCLEAR",
#   "catalogue_view_name": "tcs_view_unclear_ps1_dr1",
#   "transient_object_id": "ZTF21aarjjsb",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 47,
#   "classificationReliability": 3,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "uncertain",
#   "search_name": "ps1 faint sources r angular",
#   "raDeg": 295.344150282,
#   "decDeg": -8.80607051,
#   "original_search_radius_arcsec": 1.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 3010.13614282166,
#   "catalogue_object_subtype": null
# }
# 45

# %% [markdown]
# ### Finally - Sherlock by Position
# OK - let's try and grab Sherlock information for a star we KNOW can't be in ZTF.  What about alpha Crux.

# %%
# This is ACrux.
ra = 186.64956341666667
dec = -63.09909286111111

try:
    result = L.sherlock_position(ra, dec, lite = True)
except LasairError as e:
    print(e)

print(json.dumps(result, indent=2))
# Out:
# {
#   "classifications": {
#     "transient_00000": [
#       "VS",
#       "The transient is synonymous with <em>S7LH000444</em>; a V=1.28 mag stellar source found in the GSC catalogue. It's located 0.0\" from the stellar source core."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "VS",
#       "catalogue_table_name": "GSC",
#       "catalogue_object_id": "S7LH000444",
#       "catalogue_object_type": "star",
#       "raDeg": 186.64956583949925,
#       "decDeg": -63.09909166644884,
#       "separationArcsec": 0.01,
#       "northSeparationArcsec": "0.0048",
#       "eastSeparationArcsec": "0.0046",
#       "physical_separation_kpc": null,
#       "direct_distance": null,
#       "distance": null,
#       "z": null,
#       "photoZ": null,
#       "photoZErr": null,
#       "Mag": 1.28,
#       "MagFilter": "V",
#       "MagErr": 0.01,
#       "classificationReliability": 1
#     }
#   ]
# }
