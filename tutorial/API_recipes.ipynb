# %% [markdown]
# <p align="center">
# <img src="../lasair.png" alt="drawing" width="50"/>
# </p>
# <h1 align="center">  Lasair API Recipes </h1>
#
#
# ---
#
# ## What you'll learn
#
# This notebook will teach you the essentials for querying the Lasair API and finding the data you want:
#
# * How to do a Cone Search
# * How to find a specific `diaObjectId`
# * What data you get back and how to navigate it
# * How to make more complex queries, including Sherlock and Annotators
#
# ## Pre-requesites
#
# ### **Have you got a Lasair Token?**
#
# **_Why do I need a token to stream public alerts?_** Because without authentication systems, bad actors can mess with our servers. But creating a Lasair profile is **Free and Public** for everyone. You can do this on the [Lasair Platform](http://lasair.lsst.ac.uk/) (go to Sing-In page).
#
# Then you will be able to **see and copy your token** from your [profile](http://lasair.lsst.ac.uk/profile) page.
#
# **You should not share your token or save it in public repositories e.g. GitHub**.  One of the easies things to do so you don't have to keep pasting it, is to save it on your local machine in your shell environment. For example add this to your `bashrc` or `bash_profile`
#
# ```bash
# export LASAIR_LSST_TOKEN=blablablablablYOUROTKENHEREblablabla
# ```
#
# ### **Have you installed the `lasair` client ?**
#
# You can do this through pip!
#
# ```bash
# pip install lasair
# ```
#
# ---
#
#
# <h2 align="center">  1. Cone Search </h1>

# %%
from lasair import lasair_client as lapi
import os

# %% [markdown]
# If you have set your environment variable you can get it into python very easily!

# %%
API_TOKEN = os.getenv('LASAIR_LSST_TOKEN')

if API_TOKEN is None:
    print("No Token found. Check Spelling. Note that if you have just added your token to your environment variables, you may need to restart your terminal so your shell settings are reloaded. ")

# %% [markdown]
# Now we create our lasair API client instance, it takes in our token and the location of the Lasair API on the internet (endpoint).

# %%
L = lapi(API_TOKEN, 
         endpoint='https://api.lasair.lsst.ac.uk/api'
         )

# %% [markdown]
# Let's pick a random sky location, and set our search radius to 15 arcseconds

# %%
ra = 149.164175
dec= 2.649324
radius = 15

# %% [markdown]
# There are **3 types of Cone Searches**:
# - Count: Number of alerts found within the radius
# - Nearest: Which object is nearest (but still within the radius! If radius is too small this can be 0)
# - All: Every alert that fulfill the criteria
#
#
# ### Count

# %%
result = L.cone(ra, 
                dec, 
                radius, 
                requestType='count'
                )

print('Found %d at radius %f' % (result['count'], radius))
# Out:
# Found 6 at radius 15.000000

# %% [markdown]
# ### Nearest

# %%
result = L.cone(ra, dec, radius, requestType='nearest')
if 'nearest' in result:
    obj = result['nearest']
    print('Found %s at separation %.2f with radius %f' % (obj['object'], obj['separation'], radius))
else:
    print('No object found at radius %f' % radius)
# Out:
# Found 313998569323888791 at separation 0.20 with radius 15.000000

# %% [markdown]
# ### ALL

# %%
print('At radius %f' % radius)
result = L.cone(ra, dec, radius, requestType='all')
if 'object' in result['nearest']:
    print('nearest ', result['nearest']['object'], \
        'at separation %.2f' % result['nearest']['separation'])
    objects = result['objects']
    for obj in objects:
        print(obj['object'], "%.2f" % obj['separation'])
else:
    print('no object found')
# Out:
# At radius 15.000000
# nearest  313998569323888791 at separation 0.20
# 313998569323888791 0.20
# 170046101073166447 1.45
# 314011776099811451 1.63
# 314003015436075376 3.45
# 170050502070894741 10.50
# 170046101867462678 14.35

# %% [markdown]
# <h2 align="center">  2. Query by diaObjectId and Getting Familiar with the data</h1>

# %%
result = L.object(313761043604045880, 
                  lasair_added=True)

# %% [markdown]
# ## What data do we get?
#
# If we just print the results we can see that we have a big bundle of JSON, let's walk through the key elements

# %%
result
# Out:
# {'diaObjectId': '313761043604045880',
#  'lasairData': {'nDiaSources': 648,
#   'firstDiaSourceMjdTai': 61003.336679130254,
#   'lastDiaSourceMjdTai': 61098.11662512657,
#   'glat': -46.6423,
#   'ebv': 0.0127092,
#   'rasex': '04:07:51.557',
#   'decsex': '-48:42:48.396',
#   'ec_lon': 37.20538606288474,
#   'ec_lat': -67.08436803045953,
#   'g_lon': 256.339114704149,
#   'g_lat': -46.642267792420675,
#   'now_mjd': '61098.42',
#   'mjdmin_ago': 95.08124690709519,
#   'mjdmax_ago': 0.3013009107817197,
#   'discMjd': 61003.336679130254,
#   'discUtc': '2025-11-24 08:04:49',
#   'discMag': '1007.56±170.88',
#   'discFilter': 'r',
#   'latestMjd': 61098.11662512657,
#   'latestUtc': '2026-02-27 02:47:56',
#   'latestMag': '129197.99±641.36',
#   'latestFilter': 'r',
#   'peakMjd': 61090.09003633589,
#   'peakUtc': '2026-02-19 02:09:39',
#   'peakMag': '133318.11±620.39',
#   'peakFilter': 'z',
#   'sherlock': {'diaObjectId': 313761043604045880,
#    'classification': 'SN',
#    'association_type': 'SN',
#    'catalogue_table_name': 'DESI',
#    'catalogue_object_id': '10000,82215,16929',
#    'catalogue_object_type': 'galaxy',
#    'raDeg': 61.964776070572746,
#    'decDeg': -48.713435745556154,
#    'separationArcsec': 0.093,
#    'northSeparationArcsec': 0.0307595,
#    'eastSeparationArcsec': -0.0874541,
#    'physical_separation_kpc': None,
#    'direct_distance': None,
#    'distance': None,
#    'z': None,
#    'photoZ': None,
#    'photoZErr': None,
#    'Mag': 23.746,
#    'MagFilter': 'r',
#    'MagErr': 0.054,
#    'classificationReliability': 2,
#    'major_axis_arcsec': None,
#    'annotator': 'https://github.com/thespacedoctor/sherlock/releases/tag/v3.1.0',
#    'additional_output': 'http://lasair-lsst.lsst.ac.uk/api/sherlock/object/313761043604045880',
#    'description': 'The transient is possibly associated with <em>10000,82215,16929</em>; an r=23.75 mag galaxy found in the DESI catalogue. Its located 0.03" S, 0.09" E from the galaxy centre.',
#    'summary': None},
#   'TNS': {'ra': 61.964865,
#    'decl': -48.713235,
#    'tns_name': '2025agpz',
#    'tns_prefix': 'AT',
#    'disc_mag': 19.739,
#    'disc_mag_filter': 'cyan',
#    'disc_int_name': 'ATLAS25pny',
#    'disc_date': '10th December 2025 at 21:37:31',
#    'disc_date_mjd': 61019.90106,
#    'lastmodified_date': '13th December 2025 at 08:37:35',
#    'lastmodified_date_mjd': 61022.35943287037,
#    'sender': 'ATLAS',
#    'reporters': 'J. Tonry, L. Denneau, H. Weiland (IfA, University of Hawaii), N. Erasmus, W...',
#    'source_group': 'ATLAS',
#    'htm16': 37737915309,
#    'lasairmodified_date': '24th February 2026 at 09:29:35',
#    'lasairmodified_date_mjd': 61095.39554398148,
#    'id': 37380,
#    'diaObjectId': 313761043604045880,
#    'wl_id': 46,
#    'cone_id': 5689113,
#    'arcsec': 0.758,
#    'name': '2025agpz'},
#   'annotations': [{'annotationID': 967988,
#     'topic': 'r0b_lvra',
#     'version': 'a1',
#     'timestamp': '2026-02-27 02:55:49',
#     'classification': '0.9162399982191197',
#     'explanation': 'r0b - Real Or Bogus Classifier',
#     'classdict': '{"blame_diaSourceId": "170063691266916367", "n_gt22": 644, "n_gt21": 640, "n_gt20": 636, "n_gt19": 438, "n_gt18": 0, "brighter22": 1, "brighter21": 1, "brighter20": 1, "brighter19": 1, "brighter18": 0, "first22": 0, "first21": 0, "first20": 0, "first19": 0, "first18": 0, "model_version": "a1", "provenance_ID": "235212", "stem": "20260227_025502"}',
#     'url': 'https://lasairvras.github.io/lvra-doc/r0b.html'}],
#   'imageUrls': [{'Science': 'https://lasair.lsst.ac.uk/fits/170063691266916367_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063691266916367_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063691266916367_cutoutDifference',
#     'diaSourceId': 170063691266916367},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063691117494282_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063691117494282_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063691117494282_cutoutDifference',
#     'diaSourceId': 170063691117494282},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063690046898189_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063690046898189_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063690046898189_cutoutDifference',
#     'diaSourceId': 170063690046898189},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063689902719066_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063689902719066_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063689902719066_cutoutDifference',
#     'diaSourceId': 170063689902719066},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063689629564990_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063689629564990_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063689629564990_cutoutDifference',
#     'diaSourceId': 170063689629564990},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063689363751021_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063689363751021_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063689363751021_cutoutDifference',
#     'diaSourceId': 170063689363751021},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063689091121220_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063689091121220_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063689091121220_cutoutDifference',
#     'diaSourceId': 170063689091121220},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063688810102850_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063688810102850_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063688810102850_cutoutDifference',
#     'diaSourceId': 170063688810102850},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063688554250321_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063688554250321_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063688554250321_cutoutDifference',
#     'diaSourceId': 170063688554250321},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063688457781280_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063688457781280_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063688457781280_cutoutDifference',
#     'diaSourceId': 170063688457781280},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063688004272191_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063688004272191_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063688004272191_cutoutDifference',
#     'diaSourceId': 170063688004272191},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063687748419678_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063687748419678_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063687748419678_cutoutDifference',
#     'diaSourceId': 170063687748419678},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063687464255501_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063687464255501_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063687464255501_cutoutDifference',
#     'diaSourceId': 170063687464255501},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063687406583809_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063687406583809_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063687406583809_cutoutDifference',
#     'diaSourceId': 170063687406583809},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063687211548713_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063687211548713_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063687211548713_cutoutDifference',
#     'diaSourceId': 170063687211548713},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063687139721266_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063687139721266_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063687139721266_cutoutDifference',
#     'diaSourceId': 170063687139721266},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686871285769_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686871285769_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686871285769_cutoutDifference',
#     'diaSourceId': 170063686871285769},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686676250643_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686676250643_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686676250643_cutoutDifference',
#     'diaSourceId': 170063686676250643},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686602326051_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686602326051_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686602326051_cutoutDifference',
#     'diaSourceId': 170063686602326051},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686413058098_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686413058098_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686413058098_cutoutDifference',
#     'diaSourceId': 170063686413058098},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686288277531_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686288277531_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686288277531_cutoutDifference',
#     'diaSourceId': 170063686288277531},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063686148292655_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170063686148292655_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170063686148292655_cutoutDifference',
#     'diaSourceId': 170063686148292655},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170063685877760020_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170
cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170059270018039879_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170059270018039879_cutoutDifference',
#     'diaSourceId': 170059270018039879},
#    {'Science': 'https://lasair.lsst.ac.uk/fits/170059269837160487_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170059269837160487_cutoutTemplate',
# ...
#    'psfFluxErr': 457.64984130859375},
#   {'midpointMjdTai': 61097.14281424926,
#    'band': 'i',
#    'psfFlux': 112688.15625,
#    'psfFluxErr': 480.55712890625},
#   {'midpointMjdTai': 61097.14324658849,
#    'band': 'i',
#    'psfFlux': 112450.875,
#    'psfFluxErr': 453.54083251953125},
#   {'midpointMjdTai': 61097.14368989579,
#    'band': 'i',
#    'psfFlux': 110525.921875,
#    'psfFluxErr': 455.1658020019531},
#   {'midpointMjdTai': 61097.14473437265,
#    'band': 'i',
#    'psfFlux': 112402.59375,
#    'psfFluxErr': 468.6748962402344},
#   {'midpointMjdTai': 61097.14561531556,
#    'band': 'i',
#    'psfFlux': 112369.265625,
#    'psfFluxErr': 460.88494873046875},
#   {'midpointMjdTai': 61097.14647631266,
#    'band': 'i',
#    'psfFlux': 111217.921875,
#    'psfFluxErr': 494.8475036621094},
#   {'midpointMjdTai': 61097.16380707836,
#    'band': 'i',
#    'psfFlux': 111802.640625,
#    'psfFluxErr': 573.5810546875},
#   {'midpointMjdTai': 61097.16425407931,
#    'band': 'i',
#    'psfFlux': 110416.078125,
#    'psfFluxErr': 617.0480346679688},
#   {'midpointMjdTai': 61097.16469193583,
#    'band': 'i',
#    'psfFlux': 112092.4140625,
#    'psfFluxErr': 541.1075439453125},
#   {'midpointMjdTai': 61097.165129772635,
#    'band': 'i',
#    'psfFlux': 113709.5625,
#    'psfFluxErr': 550.0397338867188},
#   {'midpointMjdTai': 61098.02191507602,
#    'band': 'i',
#    'psfFlux': 112573.109375,
#    'psfFluxErr': 434.7611389160156},
#   {'midpointMjdTai': 61098.022355987225,
#    'band': 'i',
#    'psfFlux': 113087.7421875,
#    'psfFluxErr': 468.1965637207031},
#   {'midpointMjdTai': 61098.02278773053,
#    'band': 'i',
#    'psfFlux': 110175.6640625,
#    'psfFluxErr': 440.0859375},
#   {'midpointMjdTai': 61098.023225923025,
#    'band': 'i',
#    'psfFlux': 110176.125,
#    'psfFluxErr': 438.25469970703125},
#   {'midpointMjdTai': 61098.02410159689,
#    'band': 'i',
#    'psfFlux': 111945.625,
#    'psfFluxErr': 439.47271728515625},
#   {'midpointMjdTai': 61098.02453835474,
#    'band': 'i',
#    'psfFlux': 110890.5625,
#    'psfFluxErr': 433.0862121582031},
#   {'midpointMjdTai': 61098.02497984843,
#    'band': 'i',
#    'psfFlux': 111275.9765625,
#    'psfFluxErr': 449.582275390625},
#   {'midpointMjdTai': 61098.025853249535,
#    'band': 'i',
#    'psfFlux': 111740.65625,
#    'psfFluxErr': 433.22418212890625},
#   {'midpointMjdTai': 61098.02628099211,
#    'band': 'i',
#    'psfFlux': 110582.3046875,
#    'psfFluxErr': 428.24029541015625},
#   {'midpointMjdTai': 61098.02672317735,
#    'band': 'i',
#    'psfFlux': 112316.046875,
#    'psfFluxErr': 433.825439453125},
#   {'midpointMjdTai': 61098.027593164166,
#    'band': 'i',
#    'psfFlux': 110986.921875,
#    'psfFluxErr': 419.0731201171875},
#   {'midpointMjdTai': 61098.02802341731,
#    'band': 'i',
#    'psfFlux': -11169.62890625,
#    'psfFluxErr': 246.5793914794922},
#   {'midpointMjdTai': 61098.02856488418,
#    'band': 'i',
#    'psfFlux': 109997.2578125,
#    'psfFluxErr': 413.1155090332031},
#   {'midpointMjdTai': 61098.03030866147,
#    'band': 'i',
#    'psfFlux': 112923.71875,
#    'psfFluxErr': 450.9480285644531},
#   {'midpointMjdTai': 61098.031176037235,
#    'band': 'i',
#    'psfFlux': 112177.0859375,
#    'psfFluxErr': 428.88800048828125},
#   {'midpointMjdTai': 61098.03204956653,
#    'band': 'i',
#    'psfFlux': 111014.2578125,
#    'psfFluxErr': 417.1342468261719},
#   {'midpointMjdTai': 61098.0324797919,
#    'band': 'i',
#    'psfFlux': 111156.84375,
#    'psfFluxErr': 426.15423583984375},
#   {'midpointMjdTai': 61098.032915556105,
#    'band': 'i',
#    'psfFlux': 111801.703125,
#    'psfFluxErr': 437.1746520996094},
#   {'midpointMjdTai': 61098.033797272285,
#    'band': 'i',
#    'psfFlux': 110444.109375,
#    'psfFluxErr': 421.2542724609375},
#   {'midpointMjdTai': 61098.034226166725,
#    'band': 'i',
#    'psfFlux': 111717.8359375,
#    'psfFluxErr': 419.857421875},
#   {'midpointMjdTai': 61098.034670573776,
#    'band': 'i',
#    'psfFlux': 111604.1328125,
#    'psfFluxErr': 412.50372314453125},
#   {'midpointMjdTai': 61098.03616623148,
#    'band': 'i',
#    'psfFlux': 111430.671875,
#    'psfFluxErr': 439.23858642578125},
#   {'midpointMjdTai': 61098.037035594665,
#    'band': 'i',
#    'psfFlux': 110922.359375,
#    'psfFluxErr': 436.3269958496094},
#   {'midpointMjdTai': 61098.03747304203,
#    'band': 'i',
#    'psfFlux': 112225.5234375,
#    'psfFluxErr': 422.8680114746094},
#   {'midpointMjdTai': 61098.037909552084,
#    'band': 'i',
#    'psfFlux': 112734.3359375,
#    'psfFluxErr': 442.3871765136719},
#   {'midpointMjdTai': 61098.038350482115,
#    'band': 'i',
#    'psfFlux': 110740.921875,
#    'psfFluxErr': 425.2933044433594},
#   {'midpointMjdTai': 61098.03922727193,
#    'band': 'i',
#    'psfFlux': 112777.921875,
#    'psfFluxErr': 437.4014587402344},
#   {'midpointMjdTai': 61098.039650886356,
#    'band': 'i',
#    'psfFlux': 112071.828125,
#    'psfFluxErr': 450.7303161621094},
#   {'midpointMjdTai': 61098.04009141966,
#    'band': 'i',
#    'psfFlux': 112671.65625,
#    'psfFluxErr': 460.26422119140625},
#   {'midpointMjdTai': 61098.04095980789,
#    'band': 'i',
#    'psfFlux': 112480.2265625,
#    'psfFluxErr': 463.9526672363281},
#   {'midpointMjdTai': 61098.042874781575,
#    'band': 'g',
#    'psfFlux': 76919.125,
#    'psfFluxErr': 334.1634216308594},
#   {'midpointMjdTai': 61098.04361772858,
#    'band': 'g',
#    'psfFlux': 75873.734375,
#    'psfFluxErr': 324.4250183105469},
#   {'midpointMjdTai': 61098.044483823054,
#    'band': 'g',
#    'psfFlux': 77451.6796875,
#    'psfFluxErr': 371.3696594238281},
#   {'midpointMjdTai': 61098.04535904735,
#    'band': 'g',
#    'psfFlux': 76224.09375,
#    'psfFluxErr': 331.59381103515625},
#   {'midpointMjdTai': 61098.046224065096,
#    'band': 'g',
#    'psfFlux': 76506.1015625,
#    'psfFluxErr': 334.7316589355469},
#   {'midpointMjdTai': 61098.0470963458,
#    'band': 'g',
#    'psfFlux': 75853.546875,
#    'psfFluxErr': 313.1399230957031},
#   {'midpointMjdTai': 61098.047526293856,
#    'band': 'g',
#    'psfFlux': 77670.328125,
#    'psfFluxErr': 349.5632019042969},
#   {'midpointMjdTai': 61098.047965445134,
#    'band': 'g',
#    'psfFlux': 76864.1328125,
#    'psfFluxErr': 353.56158447265625},
#   {'midpointMjdTai': 61098.04884821577,
#    'band': 'g',
#    'psfFlux': 76602.9453125,
#    'psfFluxErr': 338.3038330078125},
#   {'midpointMjdTai': 61098.04927653936,
#    'band': 'g',
#    'psfFlux': 77667.1015625,
#    'psfFluxErr': 366.74053955078125},
#   {'midpointMjdTai': 61098.04972030628,
#    'band': 'g',
#    'psfFlux': 76063.21875,
#    'psfFluxErr': 337.9228210449219},
#   {'midpointMjdTai': 61098.0507566648,
#    'band': 'g',
#    'psfFlux': 77121.8515625,
#    'psfFluxErr': 339.4800109863281},
#   {'midpointMjdTai': 61098.05119195001,
#    'band': 'g',
#    'psfFlux': 77394.8671875,
#    'psfFluxErr': 353.2348937988281},
#   {'midpointMjdTai': 61098.0516261253,
#    'band': 'g',
#    'psfFlux': 76605.71875,
#    'psfFluxErr': 366.6346740722656},
#   {'midpointMjdTai': 61098.05250822012,
#    'band': 'g',
#    'psfFlux': 76837.5859375,
#    'psfFluxErr': 346.64306640625},
#   {'midpointMjdTai': 61098.05294764909,
#    'band': 'g',
#    'psfFlux': 77031.6953125,
#    'psfFluxErr': 364.2320251464844},
#   {'midpointMjdTai': 61098.053388787856,
#    'band': 'g',
#    'psfFlux': 75849.625,
#    'psfFluxErr': 334.9184875488281},
#   {'midpointMjdTai': 61098.05426765152,
#    'band': 'g',
#    'psfFlux': 77176.5625,
#    'psfFluxErr': 333.5703125},
#   {'midpointMjdTai': 61098.05469325709,
#    'band': 'g',
#    'psfFlux': 77777.28125,
#    'psfFluxErr': 349.4251403808594},
#   {'midpointMjdTai': 61098.05513158029,
#    'band': 'g',
#    'psfFlux': 76214.265625,
#    'psfFluxErr': 337.36724853515625},
#   {'midpointMjdTai': 61098.056003928614,
#    'band': 'g',
#    'psfFlux': 76342.421875,
#    'psfFluxErr': 329.2437438964844},
#   {'midpointMjdTai': 61098.05643118988,
#    'band': 'g',
#    'psfFlux': 75257.5390625,
#    'psfFluxErr': 342.1812744140625},
#   {'midpointMjdTai': 61098.057018869666,
#    'band': 'g',
#    'psfFlux': 76238.4921875,
#    'psfFluxErr': 338.3311767578125},
#   {'midpointMjdTai': 61098.058760022635,
#    'band': 'g',
#    'psfFlux': 75513.8984375,
#    'psfFluxErr': 326.2320251464844},
#   {'midpointMjdTai': 61098.05962571832,
#    'band': 'g',
#    'psfFlux': 76396.1484375,
#    'psfFluxErr': 339.61163330078125},
#   {'midpointMjdTai': 61098.06049439458,
#    'band': 'g',
#    'psfFlux': 76048.984375,
#    'psfFluxErr': 336.9051513671875},
#   {'midpointMjdTai': 61098.060918680596,
#    'band': 'g',
#    'psfFlux': 76461.921875,
#    'psfFluxErr': 368.3091125488281},
#   {'midpointMjdTai': 61098.061354940204,
#    'band': 'g',
#    'psfFlux': 76560.078125,
#    'psfFluxErr': 327.42303466796875},
#   {'midpointMjdTai': 61098.06223420993,
#    'band': 'g',
#    'psfFlux': 75647.515625,
#    'psfFluxErr': 334.3976745605469},
#   {'midpointMjdTai': 61098.06410694645,
#    'band': 'z',
#    'psfFlux': 128120.1875,
#    'psfFluxErr': 536.0419921875},
#   {'midpointMjdTai': 61098.06454947164,
#    'band': 'z',
#    'psfFlux': 128293.953125,
#    'psfFluxErr': 560.4994506835938},
#   {'midpointMjdTai': 61098.06566470563,
#    'band': 'z',
#    'psfFlux': 130719.53125,
#    'psfFluxErr': 590.1262817382812},
#   {'midpointMjdTai': 61098.066098642674,
#    'band': 'z',
#    'psfFlux': 131441.953125,
#    'psfFluxErr': 578.7471313476562},
#   {'midpointMjdTai': 61098.0665320902,
#    'band': 'z',
#    'psfFlux': 129018.2265625,
#    'psfFluxErr': 554.5678100585938},
#   {'midpointMjdTai': 61098.06697486707,
#    'band': 'z',
#    'psfFlux': 129524.046875,
#    'psfFluxErr': 581.6862182617188},
#   {'midpointMjdTai': 61098.067411703305,
#    'band': 'z',
#    'psfFlux': 129928.9375,
#    'psfFluxErr': 572.0851440429688},
#   {'midpointMjdTai': 61098.06785221779,
#    'band': 'z',
#    'psfFlux': 130797.8125,
#    'psfFluxErr': 582.6421508789062},
#   {'midpointMjdTai': 61098.068291873526,
#    'band': 'z',
#    'psfFlux': 131444.203125,
#    'psfFluxErr': 584.5224609375},
#   {'midpointMjdTai': 61098.06917354763,
#    'band': 'z',
#    'psfFlux': 130130.96875,
#    'psfFluxErr': 577.8223876953125},
#   {'midpointMjdTai': 61098.06959891739,
#    'band': 'z',
#    'psfFlux': 129587.53125,
#    'psfFluxErr': 585.3680419921875},
#   {'midpointMjdTai': 61098.07003917118,
#    'band': 'z',
#    'psfFlux': 131812.890625,
#    'psfFluxErr': 595.4761352539062},
#   {'midpointMjdTai': 61098.07090609014,
#    'band': 'z',
#    'psfFlux': 130937.15625,
#    'psfFluxErr': 584.457275390625},
#   {'midpointMjdTai': 61098.071344374766,
#    'band': 'z',
#    'psfFlux': 129716.65625,
#    'psfFluxErr': 582.6942138671875},
#   {'midpointMjdTai': 61098.072047366884,
#    'band': 'z',
#    'psfFlux': 130227.0703125,
#    'psfFluxErr': 598.466552734375},
#   {'midpointMjdTai': 61098.07291928056,
#    'band': 'z',
#    'psfFlux': 131485.90625,
#    'psfFluxErr': 611.6270141601562},
#   {'midpointMjdTai': 61098.07379524443,
#    'band': 'z',
#    'psfFlux': 132103.6875,
#    'psfFluxErr': 594.9028930664062},
#   {'midpointMjdTai': 61098.07553051091,
#    'band': 'z',
#    'psfFlux': 129996.53125,
#    'psfFluxErr': 562.3870849609375},
#   {'midpointMjdTai': 61098.07595410627,
#    'band': 'z',
#    'psfFlux': 129894.5390625,
#    'psfFluxErr': 596.4708862304688},
#   {'midpointMjdTai': 61098.077262111925,
#    'band': 'z',
#    'psfFlux': 130857.1015625,
#    'psfFluxErr': 577.6709594726562},
#   {'midpointMjdTai': 61098.0776911418,
#    'band': 'z',
#    'psfFlux': 129377.2109375,
#    'psfFluxErr': 588.7163696289062},
#   {'midpointMjdTai': 61098.07813291751,
#    'band': 'z',
#    'psfFlux': 129645.0,
#    'psfFluxErr': 573.8907470703125},
#   {'midpointMjdTai': 61098.07907493549,
#    'band': 'z',
#    'psfFlux': 129618.578125,
#    'psfFluxErr': 562.6981201171875},
#   {'midpointMjdTai': 61098.07950536452,
#    'band': 'z',
#    'psfFlux': 129937.171875,
#    'psfFluxErr': 588.2245483398438},
#   {'midpointMjdTai': 61098.079939641946,
#    'band': 'z',
#    'psfFlux': 130602.3671875,
#    'psfFluxErr': 560.5770874023438},
#   {'midpointMjdTai': 61098.0803748048,
#    'band': 'z',
#    'psfFlux': 129658.109375,
#    'psfFluxErr': 586.2548217773438},
#   {'midpointMjdTai': 61098.080811512955,
#    'band': 'z',
#    'psfFlux': 131288.921875,
#    'psfFluxErr': 566.6781616210938},
#   {'midpointMjdTai': 61098.08125333565,
#    'band': 'z',
#    'psfFlux': 131622.171875,
#    'psfFluxErr': 578.835693359375},
#   {'midpointMjdTai': 61098.081691713174,
#    'band': 'z',
#    'psfFlux': 130420.5859375,
#    'psfFluxErr': 588.7699584960938},
#   {'midpointMjdTai': 61098.08255593207,
#    'band': 'z',
#    'psfFlux': 129210.8515625,
#    'psfFluxErr': 584.3020629882812},
#   {'midpointMjdTai': 61098.083431547246,
#    'band': 'z',
#    'psfFlux': 132550.9375,
#    'psfFluxErr': 613.6643676757812},
#   {'midpointMjdTai': 61098.08576730031,
#    'band': 'r',
#    'psfFlux': 109625.84375,
#    'psfFluxErr': 388.86358642578125},
#   {'midpointMjdTai': 61098.08620516362,
#    'band': 'r',
#    'psfFlux': 110770.765625,
#    'psfFluxErr': 394.90338134765625},
#   {'midpointMjdTai': 61098.0866784894,
#    'band': 'r',
#    'psfFlux': 111137.6171875,
#    'psfFluxErr': 399.5003967285156},
#   {'midpointMjdTai': 61098.08754500734,
#    'band': 'r',
#    'psfFlux': 111229.8046875,
#    'psfFluxErr': 415.5675354003906},
#   {'midpointMjdTai': 61098.08841965604,
#    'band': 'r',
#    'psfFlux': 109980.84375,
#    'psfFluxErr': 380.35418701171875},
#   {'midpointMjdTai': 61098.08927933014,
#    'band': 'r',
#    'psfFlux': 110032.046875,
#    'psfFluxErr': 383.2704162597656},
#   {'midpointMjdTai': 61098.09015068112,
#    'band': 'r',
#    'psfFlux': 110906.21875,
#    'psfFluxErr': 387.8913879394531},
#   {'midpointMjdTai': 61098.09057780795,
#    'band': 'r',
#    'psfFlux': 111252.3671875,
#    'psfFluxErr': 448.474853515625},
#   {'midpointMjdTai': 61098.091013110825,
#    'band': 'r',
#    'psfFlux': 111473.421875,
#    'psfFluxErr': 425.72784423828125},
#   {'midpointMjdTai': 61098.091881043554,
#    'band': 'r',
#    'psfFlux': 109922.1953125,
#    'psfFluxErr': 387.9485778808594},
#   {'midpointMjdTai': 61098.092309574466,
#    'band': 'r',
#    'psfFlux': 109961.9609375,
#    'psfFluxErr': 418.4059143066406},
#   {'midpointMjdTai': 61098.09275163098,
#    'band': 'r',
#    'psfFlux': 110672.09375,
#    'psfFluxErr': 400.2319030761719},
#   {'midpointMjdTai': 61098.09347671828,
#    'band': 'r',
#    'psfFlux': 110605.03125,
#    'psfFluxErr': 424.9077453613281},
#   {'midpointMjdTai': 61098.09391434504,
#    'band': 'r',
#    'psfFlux': 110365.9296875,
#    'psfFluxErr': 403.361572265625},
#   {'midpointMjdTai': 61098.09434612334,
#    'band': 'r',
#    'psfFlux': 111497.9453125,
#    'psfFluxErr': 436.076171875},
#   {'midpointMjdTai': 61098.09522336519,
#    'band': 'r',
#    'psfFlux': 111313.3984375,
#    'psfFluxErr': 445.3057861328125},
#   {'midpointMjdTai': 61098.095659364306,
#    'band': 'r',
#    'psfFlux': 111215.3828125,
#    'psfFluxErr': 417.6309509277344},
#   {'midpointMjdTai': 61098.096089275845,
#    'band': 'r',
#    'psfFlux': 110561.984375,
#    'psfFluxErr': 430.7503967285156},
#   {'midpointMjdTai': 61098.09652848007,
#    'band': 'r',
#    'psfFlux': 111008.140625,
#    'psfFluxErr': 414.6357116699219},
#   {'midpointMjdTai': 61098.09739582523,
#    'band': 'r',
#    'psfFlux': 109628.21875,
#    'psfFluxErr': 392.88134765625},
#   {'midpointMjdTai': 61098.09827128441,
#    'band': 'r',
#    'psfFlux': 110748.9140625,
#    'psfFluxErr': 419.5627746582031},
#   {'midpointMjdTai': 61098.099579721376,
#    'band': 'r',
#    'psfFlux': 110505.7109375,
#    'psfFluxErr': 392.37615966796875},
#   {'midpointMjdTai': 61098.100095675065,
#    'band': 'r',
#    'psfFlux': 109906.9921875,
#    'psfFluxErr': 393.0145568847656},
#   {'midpointMjdTai': 61098.10096027503,
#    'band': 'r',
#    'psfFlux': 110814.9375,
#    'psfFluxErr': 426.36102294921875},
#   {'midpointMjdTai': 61098.10183018125,
#    'band': 'r',
#    'psfFlux': 110871.515625,
#    'psfFluxErr': 401.4609375},
#   {'midpointMjdTai': 61098.10269776439,
#    'band': 'r',
#    'psfFlux': 110726.2421875,
#    'psfFluxErr': 397.6456298828125},
#   {'midpointMjdTai': 61098.103567828264,
#    'band': 'r',
#    'psfFlux': 109676.90625,
#    'psfFluxErr': 404.51483154296875},
#   {'midpointMjdTai': 61098.10443691962,
#    'band': 'r',
#    'psfFlux': 110495.078125,
#    'psfFluxErr': 412.52874755859375},
#   {'midpointMjdTai': 61098.10490978138,
#    'band': 'r',
#    'psfFlux': 112989.078125,
#    'psfFluxErr': 505.1884460449219},
#   {'midpointMjdTai': 61098.11618949568,
#    'band': 'z',
#    'psfFlux': 132655.71875,
#    'psfFluxErr': 658.3154296875},
#   {'midpointMjdTai': 61098.11662512657,
#    'band': 'z',
#    'psfFlux': 131697.34375,
#    'psfFluxErr': 653.9212036132812}]}

# %% [markdown]
# ### Let's make a Difference Photometry Lightcurve (Flux and Mag)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


diff_phot = pd.DataFrame(result['diaSourcesList'])

# %%
diff_phot.head()
# Out:
#           diaSourceId  midpointMjdTai band        psfFlux  psfFluxErr  \
# 0  170063691266916367    61098.116625    z  129197.992188  641.359558
# 1  170063691117494282    61098.116189    z  129791.000000  643.892639
# 2  170063690046898189    61098.104910    r  108911.015625  486.943481
# 3  170063689902719066    61098.104437    r  107669.828125  401.853455
# 4  170063689629564990    61098.103568    r  107207.695312  395.394440
#
#    reliability
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
def nJy2mag(nJy):
    return -2.5 * np.log10(nJy / 3631e9)

# %%
diff_phot['mag'] = nJy2mag(diff_phot['psfFlux'])
diff_phot['merr'] = np.abs(1.0857 * diff_phot['psfFluxErr'] / diff_phot['psfFlux'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
colour_dict = {'u': '#1600ea', 'g': '#31de1f', 'r': '#b52626', 'i': '#370201', 'z': '#ba52ff', 'y': '#61a2b3'}
diff_phot['colour'] = diff_phot['band'].map(colour_dict)

# %%
diff_phot['colour']
# Out:
# 0      #ba52ff
# 1      #ba52ff
# 2      #b52626
# 3      #b52626
# 4      #b52626
#         ...
# 644    #ba52ff
# 645    #370201
# 646    #b52626
# 647    #b52626
# 648    #b52626
# Name: colour, Length: 649, dtype: object

# %%
plt.scatter(diff_phot['midpointMjdTai'], 
            diff_phot['mag'], 
            c=diff_phot['colour'])
plt.errorbar(diff_phot['midpointMjdTai'],
            diff_phot['mag'], 
            yerr=diff_phot['merr'], 
            fmt='none', 
            ecolor=diff_phot['colour'])
plt.gca().invert_yaxis()
plt.xlabel('MJD')
plt.ylabel('Magnitude')

plt.title('Difference Photometry Lightcurve (AB Mag)')
# Out:
# Text(0.5, 1.0, 'Difference Photometry Lightcurve (AB Mag)')

# %%
plt.scatter(diff_phot['midpointMjdTai'], 
            diff_phot['psfFlux'], 
            c=diff_phot['colour'])

plt.errorbar(diff_phot['midpointMjdTai'],
                    diff_phot['psfFlux'], 
                    yerr=diff_phot['psfFluxErr'], 
                    fmt='none', 
                    ecolor=diff_phot['colour'], 
                    alpha=0.5)

plt.xlabel('MJD')
plt.ylabel('PSF Flux')

plt.title('Difference Photometry Lightcurve (nano Janskies)')
# Out:
# Text(0.5, 1.0, 'Difference Photometry Lightcurve (nano Janskies)')

# %% [markdown]
# ### Let's make a Forced Photometry Lightcurve (Flux and Mag)

# %%
forced_phot = pd.DataFrame(result['diaForcedSourcesList'])

# %%
forced_phot.head()
# Out:
#    midpointMjdTai band        psfFlux  psfFluxErr
# 0    61088.098045    r  113221.914062  337.557556
# 1    61088.098476    r  112091.304688  326.910553
# 2    61090.047584    i  115302.945312  432.875427
# 3    61090.048021    i  114243.554688  419.904602
# 4    61090.053544    i  114249.398438  415.129150

# %%
forced_phot['colour'] = forced_phot['band'].map(colour_dict)

# %%
plt.scatter(forced_phot['midpointMjdTai'], 
            forced_phot['psfFlux'], 
            c=forced_phot['colour'])

plt.errorbar(forced_phot['midpointMjdTai'],
                    forced_phot['psfFlux'], 
                    yerr=forced_phot['psfFluxErr'], 
                    fmt='none', 
                    ecolor=forced_phot['colour'], 
                    alpha=0.5)

plt.xlabel('MJD')
plt.ylabel('PSF Flux')

plt.title('Difference Photometry Lightcurve (nano Janskies)')
# Out:
# Text(0.5, 1.0, 'Difference Photometry Lightcurve (nano Janskies)')

# %%
forced_phot['mag'] = nJy2mag(forced_phot['psfFlux'])
forced_phot['merr'] = np.abs(1.0857 * forced_phot['psfFluxErr'] / forced_phot['psfFlux'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(forced_phot['midpointMjdTai'], forced_phot['mag'], c=forced_phot['colour'])
plt.errorbar(forced_phot['midpointMjdTai'],
            forced_phot['mag'], 
            yerr=forced_phot['merr'], 
            fmt='none', 
            ecolor=forced_phot['colour'])
plt.gca().invert_yaxis()
plt.xlabel('MJD')
plt.ylabel('Magnitude')

plt.title('Forced Photometry Lightcurve (AB Mag)')
# Out:
# Text(0.5, 1.0, 'Forced Photometry Lightcurve (AB Mag)')

# %% [markdown]
# <h2 align="center">  3. Advanced Queries </h1>
#
# You can build advanced SQL-like queries for more refinded searches. In this example we will look at finding objects based on their [Sherlock](https://lasair.readthedocs.io/en/main/core_functions/sherlock.html#sherlock--sky-context-) Classification, which is based on catalogue cross-matching.
#
#
# ### Select your data
# First let's define the **columns we want to get out of our query**: here it will be the `diaObjectId`, Ra and Dec.
#
# Since we're doing an SQL query, we need to know the correct name for the table and columns, which you can find on the [Lasair Website Schema Browser](https://lasair-lsst-dev.lsst.ac.uk/schema/)
#
#
# ![schema_browser](img/schema_browser.png)

# %%
selected = 'objects.diaObjectId, objects.ra, objects.decl'

# %% [markdown]
# ### Select your conditions
#
# The next thing we want to do is format our conditions, where we want the data **only if Sherlock said it could be a SN** (i.e. near a galaxy but not at the nucleus).
#
# Scrollking down on our Schema Broswer we can see there is a `sherlock_classification` with a `classification` column. We'll need that == `SN`
#
# ![schema_browser](img/schema_browser_sherlock.png)

# %%
conditions = 'classification="SN"'

# %% [markdown]
# ### List the tables needed for your query

# %%
tables = 'objects,sherlock_classifications'

# %% [markdown]
# ### Call your query!
#
# You'll notice here we also set a limit of 8, because a lot of objects actually match this condition.

# %%
results = L.query(selected, tables, conditions, limit = 8)

# %%
results
# Out:
# [{'diaObjectId': 170019696254910754,
#   'ra': 62.00489102706123,
#   'decl': -49.480107426965155},
#  {'diaObjectId': 170019696255435601,
#   'ra': 61.968117601750194,
#   'decl': -49.66424587878178},
#  {'diaObjectId': 170019696255435832,
#   'ra': 61.870113867720846,
#   'decl': -49.658723098270656},
#  {'diaObjectId': 170019696256483349,
#   'ra': 62.034412310614165,
#   'decl': -49.402104967251574},
#  {'diaObjectId': 170019696256483390,
#   'ra': 61.88140266821427,
#   'decl': -49.424357557495945},
#  {'diaObjectId': 170019696256483399,
#   'ra': 62.080921093801514,
#   'decl': -49.282687331866626},
#  {'diaObjectId': 170019696256483574,
#   'ra': 62.01929036473879,
#   'decl': -49.237942868780024},
#  {'diaObjectId': 170019696262250510,
#   'ra': 60.768492533476206,
#   'decl': -50.18300538789092}]

# %% [markdown]
# <h2 align="center">  4. Querying an Annotator </h2>
#
#
# [Annotations](https://lasair-lsst.readthedocs.io/en/main/concepts.html#annotations) are a really important Lasair concept which allows the community to **flexibly enrich the alert stream**.
#
# You can build filters that use annotators and you can also query the database on annotator properties!
#
# Here I'll demonstrate by querying one of the [Lasair Virtual Research Assistants or VRAs](https://lasairvras.github.io/lvra-doc/intro.html).
# It scores the alert between 0 and 1 (0=bogus, 1=real) and comes with a few flags. We'll be selecting Objects with score > 0.8 and also looking at flag `first22` which is true if it is the first time an object has become brighter than ABmag 22.
#
#
# Annotators have two main fields:
# - classification: one entry (float, int or string)
# - classdict: A free form dictionary, meaning it can contain whatever the annotator wanted to put in it!
#
# In this VRA example the real/bogus score is in the `classification` field, whislt the miscellenaous flags are in the `classdict`. To get to those fields there is a `JSON_EXTRACT` SQL function we can use! (See below).
#
# Like we did previously we need the chose **the data to select(retrieve) from the database**, the list of **tables** relevant to the query, and the **conditions**.

# %%
selected = """
objects.diaObjectId, r0b_lvra.classification as real0rbogus,
JSON_EXTRACT(r0b_lvra.classdict, '$.first22') as first22
"""

# Join objects and sherlock_classifications
tables = 'objects,annotator:r0b_lvra'

conditions = """r0b_lvra.classification > 0.8 AND JSON_EXTRACT(r0b_lvra.classdict, '$.first22') = '1'
"""

# %% [markdown]
# Send the query and limit to 10 for now:

# %%
results = L.query(selected, tables, conditions, limit = 10)

# %%
results
# Out:
# [{'diaObjectId': 313994140807331881,
#   'real0rbogus': '0.9128373128269016',
#   'first22': '1'},
#  {'diaObjectId': 313853533574135818,
#   'real0rbogus': '0.9675376047251804',
#   'first22': '1'},
#  {'diaObjectId': 313871015593115719,
#   'real0rbogus': '0.9539662466453381',
#   'first22': '1'},
#  {'diaObjectId': 313980947917701210,
#   'real0rbogus': '0.973550349318548',
#   'first22': '1'},
#  {'diaObjectId': 313756671399690520,
#   'real0rbogus': '0.9368786384599375',
#   'first22': '1'},
#  {'diaObjectId': 313967752408203426,
#   'real0rbogus': '0.880613548463611',
#   'first22': '1'},
#  {'diaObjectId': 170028487039516827,
#   'real0rbogus': '0.827999734568367',
#   'first22': '1'},
#  {'diaObjectId': 170046090629874410,
#   'real0rbogus': '0.8341922996295031',
#   'first22': '1'},
#  {'diaObjectId': 170046090036381228,
#   'real0rbogus': '0.9711740572291513',
#   'first22': '1'},
#  {'diaObjectId': 170046089933619313,
#   'real0rbogus': '0.965575032132114',
#   'first22': '1'}]

# %% [markdown]
# ---
#
#
#
#
# <h2 align="center"> How to Get Help </h2>
#
# If you have a question or need any help, you can find past questions or as a new one on the **[Community Forum](https://community.lsst.org/c/support/support-lasair/55)**.
#
#
# ![communityforum](img/community_forum.png)
